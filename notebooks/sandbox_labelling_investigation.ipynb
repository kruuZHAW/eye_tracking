# %%
import os
from pathlib import Path

store_dir = "/store/kruu/eye_tracking/training_data"

# %% [markdown]
# ****
# # Whole task detection
# ****

# %%
from utils.helper import load_and_process_et

features = ['Recording timestamp [ms]', 'epoch_ms', 'Gaze point X [DACS px]', 'Gaze point Y [DACS px]', 'Event']
interpolate_cols = ['Gaze point X [DACS px]', 'Gaze point Y [DACS px]']
fill_columns = ['Gaze point X [DACS px]', 'Gaze point Y [DACS px]']

chunks_et_without_filtering, blinks_without_filtering, atco_task_map = load_and_process_et(root_dir = store_dir,
                                                            columns = features,
                                                            filter_outliers = False,
                                                            interpolate_cols = interpolate_cols,
                                                            fill_cols = fill_columns, 
                                                            time_resampling=False,)

chunks_et_with_filtering, blinks_with_filtering, atco_task_map = load_and_process_et(root_dir = store_dir,
                                                            columns = features,
                                                            filter_outliers = True,
                                                            interpolate_cols = interpolate_cols,
                                                            fill_cols = fill_columns, 
                                                            time_resampling=False,)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 interpolate_cols = ['Gaze point X [DACS px]', 'Gaze point Y [DACS px]']
#       5 fill_columns = ['Gaze point X [DACS px]', 'Gaze point Y [DACS px]']
# ----> 7 chunks_et_without_filtering, blinks_without_filtering, atco_task_map = load_and_process_et(root_dir = store_dir,
#       8                                                             columns = features,
#       9                                                             filter_outliers = False,
#      10                                                             interpolate_cols = interpolate_cols,
#      11                                                             fill_cols = fill_columns,
#      12                                                             time_resampling=False,)
#      14 chunks_et_with_filtering, blinks_with_filtering, atco_task_map = load_and_process_et(root_dir = store_dir,
#      15                                                             columns = features,
#      16                                                             filter_outliers = True,
#      17                                                             interpolate_cols = interpolate_cols,
#      18                                                             fill_cols = fill_columns,
#      19                                                             time_resampling=False,)
#
# File ~/git_folder/eye_tracking/utils/helper.py:42, in load_and_process_et(root_dir, columns, filter_outliers, interpolate_cols, fill_cols, window_short_ms, window_mid_ms, window_long_ms, task_margin_ms, step_ms, participants, scenarios, time_resampling)
#      39 scenarios, atco_task_map = processor.load_data(et_file_index, want_columns=list(needed))
#      41 # Blink detection
# ---> 42 scenarios_with_blinks, blink_summaries = processor.detect_blinks_in_streams(scenarios)
#      44 ###### Chunking Strategy ######
#      45 if (window_short_ms is not None) & (window_mid_ms is not None) & (window_long_ms is not None):
#
# File ~/git_folder/eye_tracking/utils/data_processing_gaze_data.py:791, in EyeTrackingProcessor.detect_blinks_in_streams(self, dfs, blink_threshold)
#     788 scenario_id = str(df.get("scenario_id", pd.Series(["unknown"])).iloc[0])
#     789 key = f"{participant}_{scenario_id}"
# --> 791 updated_df, summary_df = self._detect_blinks_in_scenario(df, blink_threshold=blink_threshold)
#     792 updated_dfs.append(updated_df)
#     793 all_blinks[key] = summary_df
#
# File ~/git_folder/eye_tracking/utils/data_processing_gaze_data.py:702, in EyeTrackingProcessor._detect_blinks_in_scenario(self, df, blink_threshold)
#     696 df["_run"] = df["Missing Gaze"].ne(df["Missing Gaze"].shift(fill_value=False)).cumsum()
#     698 # Duration per run (sum of diffs) using only missing-gaze rows
#     699 dur_by_run = (
#     700     df.loc[df["Missing Gaze"], [self.timestamp_col, "_run"]]
#     701     .groupby("_run")[self.timestamp_col]
# --> 702     .apply(lambda s: (s.diff().fillna(0)).sum())
#     703 )
#     705 # Which runs count as blinks/attention loss
#     706 if dur_by_run.empty:
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py:230, in SeriesGroupBy.apply(self, func, *args, **kwargs)
#     224 @Appender(
#     225     _apply_docs["template"].format(
#     226         input="series", examples=_apply_docs["series_examples"]
#     227     )
#     228 )
#     229 def apply(self, func, *args, **kwargs) -> Series:
# --> 230     return super().apply(func, *args, **kwargs)
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1824, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1822 with option_context("mode.chained_assignment", None):
#    1823     try:
# -> 1824         result = self._python_apply_general(f, self._selected_obj)
#    1825         if (
#    1826             not isinstance(self.obj, Series)
#    1827             and self._selection is None
#    1828             and self._selected_obj.shape != self._obj_with_exclusions.shape
#    1829         ):
#    1830             warnings.warn(
#    1831                 message=_apply_groupings_depr.format(
#    1832                     type(self).__name__, "apply"
#    (...)   1835                 stacklevel=find_stack_level(),
#    1836             )
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1850 @final
#    1851 def _python_apply_general(
#    1852     self,
#    (...)   1857     is_agg: bool = False,
#    1858 ) -> NDFrameT:
#    1859     """
#    1860     Apply function f in python space
#    1861
#    (...)   1883         data after applying f
#    1884     """
# -> 1885     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886     if not_indexed_same is None:
#    1887         not_indexed_same = mutated
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/groupby/ops.py:919, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     917 # group might be modified
#     918 group_axes = group.axes
# --> 919 res = f(group)
#     920 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     921     mutated = True
#
# File ~/git_folder/eye_tracking/utils/data_processing_gaze_data.py:702, in EyeTrackingProcessor._detect_blinks_in_scenario.<locals>.<lambda>(s)
#     696 df["_run"] = df["Missing Gaze"].ne(df["Missing Gaze"].shift(fill_value=False)).cumsum()
#     698 # Duration per run (sum of diffs) using only missing-gaze rows
#     699 dur_by_run = (
#     700     df.loc[df["Missing Gaze"], [self.timestamp_col, "_run"]]
#     701     .groupby("_run")[self.timestamp_col]
# --> 702     .apply(lambda s: (s.diff().fillna(0)).sum())
#     703 )
#     705 # Which runs count as blinks/attention loss
#     706 if dur_by_run.empty:
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/generic.py:7349, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7342     else:
#    7343         raise TypeError(
#    7344             '"value" parameter must be a scalar, dict '
#    7345             "or Series, but you passed a "
#    7346             f'"{type(value).__name__}"'
#    7347         )
# -> 7349     new_data = self._mgr.fillna(
#    7350         value=value, limit=limit, inplace=inplace, downcast=downcast
#    7351     )
#    7353 elif isinstance(value, (dict, ABCSeries)):
#    7354     if axis == 1:
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/internals/base.py:186, in DataManager.fillna(self, value, limit, inplace, downcast)
#     182 if limit is not None:
#     183     # Do this validation even if we go through one of the no-op paths
#     184     limit = libalgos.validate_limit(None, limit=limit)
# --> 186 return self.apply_with_block(
#     187     "fillna",
#     188     value=value,
#     189     limit=limit,
#     190     inplace=inplace,
#     191     downcast=downcast,
#     192     using_cow=using_copy_on_write(),
#     193     already_warned=_AlreadyWarned(),
#     194 )
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1692, in Block.fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#    1686     nbs = self.putmask(
#    1687         mask.T, value, using_cow=using_cow, already_warned=already_warned
#    1688     )
#    1689 else:
#    1690     # without _downcast, we would break
#    1691     #  test_fillna_dtype_conversion_equiv_replace
# -> 1692     nbs = self.where(value, ~mask.T, _downcast=False)
#    1694 # Note: blk._maybe_downcast vs self._maybe_downcast(nbs)
#    1695 #  makes a difference bc blk may have object dtype, which has
#    1696 #  different behavior in _maybe_downcast.
#    1697 return extend_blocks(
#    1698     [
#    1699         blk._maybe_downcast(
#    (...)   1703     ]
#    1704 )
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1554, in Block.where(self, other, cond, _downcast, using_cow)
#    1551 if transpose:
#    1552     values = values.T
# -> 1554 icond, noop = validate_putmask(values, ~cond)
#    1555 if noop:
#    1556     # GH-39595: Always return a copy; short-circuit up/downcasting
#    1557     if using_cow:
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/pandas/core/array_algos/putmask.py:111, in validate_putmask(values, mask)
#     108 if mask.shape != values.shape:
#     109     raise ValueError("putmask: mask and data must be the same size")
# --> 111 noop = not mask.any()
#     112 return mask, noop
#
# File ~/git_folder/eye_tracking/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:64, in _any(a, axis, dtype, out, keepdims, where)
#      62 # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      63 if where is True:
# ---> 64     return umr_any(a, axis, dtype, out, keepdims)
#      65 return umr_any(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %%
atco_task_map
# Out:
# {'Aircraft requests': 'Task 0',
#  'Assume': 'Task 1',
#  'Conflict resolution': 'Task 2',
#  'Entry conditions': 'Task 3',
#  'Entry conflict resolution': 'Task 4',
#  'Entry coordination': 'Task 5',
#  'Exit conditions': 'Task 6',
#  'Exit conflict resolution': 'Task 7',
#  'Exit coordination': 'Task 8',
#  'Non-conformance resolution': 'Task 9',
#  'QoS': 'Task 10',
#  'Return to route': 'Task 11',
#  'Transfer': 'Task 12',
#  'Zone conflict': 'Task 13'}

# %%
# For whole tasks

from collections import defaultdict
import numpy as np

durations_by_task = defaultdict(list)
task_count = defaultdict(int)

for df in chunks_et_without_filtering.values():
    task_id = int(df["Task_id"].iloc[0])
    task_count[task_id] += 1

    ts_col = "Recording timestamp [ms]"
    ts = df[ts_col].astype(float)
    dur_ms = float(ts.max() - ts.min())

    durations_by_task[task_id].append(dur_ms)

mean_ms_by_task = {task: float(np.mean(durs)) for task, durs in durations_by_task.items()}
med_ms_by_task = {task: float(np.median(durs)) for task, durs in durations_by_task.items()}
max_ms_by_task = {task: float(np.max(durs)) for task, durs in durations_by_task.items()}
min_ms_by_task = {task: float(np.min(durs)) for task, durs in durations_by_task.items()}

# The mean and median should be close. Otherwise we have a lot of outliers
for task_id in sorted(max_ms_by_task):
    print(f"Task {task_id}: {mean_ms_by_task[task_id]/1000:.3f}s, {med_ms_by_task[task_id]/1000:.3f}s [{min_ms_by_task[task_id]/1000:.3f}, {max_ms_by_task[task_id]/1000:.3f}] s")
    
print("\n")
print(task_count)
# Out:
# Task 0: 15.254s, 12.438s [0.821, 94.872] s
# Task 1: 8.351s, 7.177s [0.371, 492.926] s
# Task 2: 18.405s, 9.908s [2.059, 1340.954] s
# Task 3: 18.934s, 18.034s [2.226, 62.712] s
# Task 4: 19.955s, 19.255s [1.582, 62.712] s
# Task 5: 18.848s, 17.352s [1.021, 105.677] s
# Task 6: 12.504s, 9.273s [1.232, 70.116] s
# Task 7: 13.627s, 7.894s [1.628, 53.879] s
# Task 8: 18.497s, 16.043s [1.705, 76.243] s
# Task 9: 15.843s, 13.396s [4.493, 40.152] s
# Task 10: 8.332s, 7.362s [0.540, 32.903] s
# Task 11: 9.328s, 8.302s [0.011, 44.322] s
# Task 12: 11.216s, 7.862s [0.004, 3284.167] s
# Task 13: 12.221s, 9.969s [1.011, 302.949] s
#
#
# defaultdict(<class 'int'>, {5: 293, 1: 1753, 13: 752, 9: 50, 0: 313, 2: 301, 12: 1720, 11: 508, 8: 209, 6: 123, 4: 25, 10: 334, 3: 63, 7: 16})

# %%
durations_by_task = defaultdict(list)
task_count = defaultdict(int)

for df in chunks_et_with_filtering.values():
    task_id = int(df["Task_id"].iloc[0])
    task_count[task_id] += 1

    ts_col = "Recording timestamp [ms]"
    ts = df[ts_col].astype(float)
    dur_ms = float(ts.max() - ts.min())

    durations_by_task[task_id].append(dur_ms)

mean_ms_by_task = {task: float(np.mean(durs)) for task, durs in durations_by_task.items()}
med_ms_by_task = {task: float(np.median(durs)) for task, durs in durations_by_task.items()}
max_ms_by_task = {task: float(np.max(durs)) for task, durs in durations_by_task.items()}
min_ms_by_task = {task: float(np.min(durs)) for task, durs in durations_by_task.items()}

# The mean and median should be close. Otherwise we have a lot of outliers
for task_id in sorted(max_ms_by_task):
    print(f"Task {task_id}: {mean_ms_by_task[task_id]/1000:.3f}s, {med_ms_by_task[task_id]/1000:.3f}s [{min_ms_by_task[task_id]/1000:.3f}, {max_ms_by_task[task_id]/1000:.3f}] s")
    
print("\n")

print(task_count)
# Out:
# Task 0: 14.837s, 12.330s [0.821, 53.370] s
# Task 1: 7.727s, 7.106s [0.715, 26.745] s
# Task 2: 11.221s, 9.603s [2.059, 36.805] s
# Task 3: 18.228s, 18.005s [2.226, 47.518] s
# Task 4: 19.955s, 19.255s [1.582, 62.712] s
# Task 5: 18.075s, 17.317s [1.021, 47.518] s
# Task 6: 11.502s, 9.184s [1.232, 37.135] s
# Task 7: 10.944s, 7.773s [1.628, 32.910] s
# Task 8: 17.731s, 15.836s [1.705, 52.108] s
# Task 9: 15.843s, 13.396s [4.493, 40.152] s
# Task 10: 8.192s, 7.322s [0.540, 26.931] s
# Task 11: 9.062s, 8.257s [0.787, 30.014] s
# Task 12: 8.109s, 7.801s [0.540, 25.344] s
# Task 13: 10.435s, 9.764s [1.011, 33.280] s
#
#
# defaultdict(<class 'int'>, {5: 289, 1: 1732, 13: 737, 9: 50, 0: 311, 2: 290, 12: 1701, 11: 502, 8: 206, 6: 120, 4: 25, 10: 332, 3: 62, 7: 15})

# %% [markdown]
# A cleaning step is needed here to remove annotation errors. Added in data_processing_gaze_data.task_range_finder.
#
# Procedure:
# - Remove tasks where duration < 0.5s
# - Discard bounds that are outside quantile rule:
#     - Upper bound = Q3 + 3 * IQR
#     - Lower bound = max(0.5s, Q1 - 1.5 * IQR)

# %% [markdown]
# ****
# # New labelling strategy
# ****

# %% [markdown]
# - Prediction at time t:
#     - Label = task at time t
#     - define marin around eah task boundary (ex 2/3s) to avoid noise
#     - Option: use sample weights to soften boundary samples (e.g. fraction of the last 10s that belongs to the labeled task), and use that purity as a sample weight in XGboost. The model pay less attention to the ambiguous cases.
#     - Option: hack sfot labels in XGboost. Ex window has 70% Task 1, and 30% idle
#         - Create two training rows with the same features but with different labels (label Task 1, weight 0.7 / label idle, weight 0.3)
#         - Train XGBoost with sample weight.
#         - Gradient contributions approximate soft labels
#         - Mix with end-anchored idea: label by task at time t (for evaluation), but distribute training weights according to window composition
# - 3 windows:
#     - short (3-5s), mid (10-15s) and long (25-40s) terms
#         - Short: captures immediate events (clicks, fixatino, saccades)
#         - Mid: typical average task length region
#         - Long: context
#     - Extract features separately on each window (prefix features names like short_*, mid_*, long_*)
#     - Concatenate all these features into a single vector.
#     - Label the training row wit the task active at time t (or idle if none)
#     - "Given what happened in the last S/M/L seconds up to time t, what is the controller doing now?"

# %%
from utils.helper import load_and_process_et

# 30 mins

store_dir = "/store/kruu/eye_tracking/training_data"
features = ['Recording timestamp [ms]', 'epoch_ms', 'Gaze point X [DACS px]', 'Gaze point Y [DACS px]', 'Event']
interpolate_cols = ['Gaze point X [DACS px]', 'Gaze point Y [DACS px]']
fill_columns = ['Gaze point X [DACS px]', 'Gaze point Y [DACS px]']

chunks_et, blinks, atco_task_map = load_and_process_et(root_dir = store_dir,
                                                            columns = features,
                                                            interpolate_cols = interpolate_cols,
                                                            fill_cols = fill_columns,
                                                            window_short_ms = 5000,
                                                            window_mid_ms = 10000,
                                                            window_long_ms = 25000,
                                                            task_margin_ms = 2000,
                                                            step_ms = 3000,
                                                            filter_outliers = True,
                                                            time_resampling=False)
# Out:
# ⚠️ Unmatched 'end' for Task 5 at 3459514
# ⚠️ Unmatched 'start' for Task 3 at 3443448
# ⚠️ Unmatched 'end' for Task 5 at 1475678
# ⚠️ Unmatched 'end' for Task 3 at 732128
# ⚠️ Unmatched 'end' for Task 8 at 1168579
# ⚠️ Unmatched 'end' for Task 1 at 1407071
# ⚠️ Unmatched 'start' for Task 12 at 1171948
# ⚠️ Unmatched 'end' for Task 7 at 1407679
# ⚠️ Unmatched 'end' for Task 8 at 3096761
# ⚠️ Unmatched 'end' for Task 0 at 3174255
# ⚠️ Unmatched 'start' for Task 1 at 695652
# ⚠️ Unmatched 'start' for Task 12 at 3785377
# ⚠️ Unmatched 'start' for Task 13 at 3467085
# ⚠️ Unmatched 'start' for Task 13 at 3467602
# ⚠️ Unmatched 'start' for Task 13 at 3467757
# ⚠️ Unmatched 'start' for Task 6 at 1395939
# ⚠️ Unmatched 'start' for Task 4 at 3513371
# ⚠️ Unmatched 'end' for Task 1 at 2525380
# ⚠️ Unmatched 'end' for Task 13 at 3253527
# ⚠️ Unmatched 'start' for Task 12 at 3248347
# ⚠️ Unmatched 'end' for Task 13 at 2910462
# ⚠️ Unmatched 'end' for Task 7 at 3179705
# ⚠️ Unmatched 'end' for Task 1 at 346849
# ⚠️ Unmatched 'end' for Task 12 at 815514
# ⚠️ Unmatched 'end' for Task 12 at 884947
# ⚠️ Unmatched 'end' for Task 12 at 887080
# ⚠️ Unmatched 'end' for Task 8 at 957579
# ⚠️ Unmatched 'end' for Task 13 at 1010556
# ⚠️ Unmatched 'end' for Task 13 at 1096176
# ⚠️ Unmatched 'end' for Task 13 at 1311628
# ⚠️ Unmatched 'end' for Task 13 at 1319967
# ⚠️ Unmatched 'end' for Task 8 at 1364041
# ⚠️ Unmatched 'end' for Task 12 at 1378949
# ⚠️ Unmatched 'end' for Task 13 at 1421535
# ⚠️ Unmatched 'end' for Task 13 at 1866313
# ⚠️ Unmatched 'end' for Task 13 at 1878613
# ⚠️ Unmatched 'end' for Task 13 at 1912223
# ⚠️ Unmatched 'end' for Task 13 at 1924307
# ⚠️ Unmatched 'end' for Task 13 at 2179696
# ⚠️ Unmatched 'end' for Task 13 at 2309476
# ⚠️ Unmatched 'end' for Task 3 at 2715224
# ⚠️ Unmatched 'end' for Task 13 at 2778212
# ⚠️ Unmatched 'end' for Task 13 at 2899282
# ⚠️ Unmatched 'start' for Task 13 at 3650104
# ⚠️ Unmatched 'start' for Task 6 at 1350277
# ⚠️ Unmatched 'end' for Task 1 at 10492
# ⚠️ Unmatched 'end' for Task 5 at 357881
# ⚠️ Unmatched 'end' for Task 12 at 2140153
# ⚠️ Unmatched 'end' for Task 12 at 2152434
# ⚠️ Unmatched 'end' for Task 0 at 2546911
# ⚠️ Unmatched 'start' for Task 1 at 10492
# ⚠️ Unmatched 'start' for Task 12 at 1035423
# ⚠️ Unmatched 'start' for Task 4 at 411413
# ⚠️ Unmatched 'start' for Task 4 at 430256
# ⚠️ Unmatched 'start' for Task 4 at 442300
# ⚠️ Unmatched 'start' for Task 13 at 1091083
# ⚠️ Unmatched 'end' for Task 10 at 1047573
# ⚠️ Unmatched 'start' for Task 10 at 1056268
# ⚠️ Unmatched 'end' for Task 7 at 3565790
# ⚠️ Unmatched 'end' for Task 10 at 3747983
# ⚠️ Unmatched 'start' for Task 11 at 3739610
# ⚠️ Unmatched 'start' for Task 6 at 3558720
# ⚠️ Unmatched 'end' for Task 1 at 449451
# ⚠️ Unmatched 'start' for Task 12 at 910932
# ⚠️ Unmatched 'end' for Task 2 at 279822
# ⚠️ Unmatched 'end' for Task 2 at 282033
# ⚠️ Unmatched 'end' for Task 4 at 995740
# ⚠️ Unmatched 'end' for Task 8 at 3031455
# ⚠️ Unmatched 'end' for Task 7 at 3125629
# ⚠️ Unmatched 'start' for Task 3 at 979539
# ⚠️ Unmatched 'start' for Task 6 at 2989803
# ⚠️ Unmatched 'start' for Task 6 at 3119534
# ⚠️ Unmatched 'end' for Task 13 at 1463675
# ⚠️ Unmatched 'end' for Task 5 at 268385
# ⚠️ Unmatched 'start' for Task 3 at 253311
# ⚠️ Unmatched 'end' for Task 8 at 346422
# ⚠️ Unmatched 'end' for Task 3 at 669788
# ⚠️ Unmatched 'end' for Task 11 at 2004437
# ⚠️ Unmatched 'start' for Task 12 at 1999080
# ⚠️ Unmatched 'start' for Task 4 at 658499
# ⚠️ Unmatched 'end' for Task 3 at 2240089
# ⚠️ Unmatched 'start' for Task 1 at 1288240
# ⚠️ Unmatched 'start' for Task 1 at 2419810
# ⚠️ Unmatched 'start' for Task 2 at 1336720
# ⚠️ Unmatched 'start' for Task 2 at 1384217
# ⚠️ Unmatched 'start' for Task 8 at 2222645
# ⚠️ Unmatched 'start' for Task 6 at 1631738
# ⚠️ Unmatched 'start' for Task 6 at 1719120
# ⚠️ Unmatched 'end' for Task 5 at 1511042
# ⚠️ Unmatched 'start' for Task 3 at 1493000
# ⚠️ Unmatched 'end' for Task 1 at 737258
# ⚠️ Unmatched 'start' for Task 0 at 721416
# ⚠️ Unmatched 'start' for Task 1 at 3897662
# ⚠️ Unmatched 'end' for Task 8 at 3014348
# ⚠️ Unmatched 'start' for Task 3 at 1759617
# ⚠️ Unmatched 'start' for Task 3 at 2434454
# ⚠️ Unmatched 'start' for Task 7 at 2328448
# ⚠️ Unmatched 'end' for Task 6 at 300941
# ⚠️ Unmatched 'start' for Task 1 at 125438
# ⚠️ Unmatched 'end' for Task 11 at 1802681
# ⚠️ Unmatched 'start' for Task 0 at 896939
# ⚠️ Unmatched 'start' for Task 5 at 3162810
# ⚠️ Unmatched 'end' for Task 8 at 3240615
# ⚠️ Unmatched 'start' for Task 5 at 3216417
# ⚠️ Unmatched 'end' for Task 6 at 1790188
# ⚠️ Unmatched 'end' for Task 1 at 670917
# ⚠️ Unmatched 'end' for Task 1 at 670917
# ⚠️ Unmatched 'end' for Task 13 at 1410331
# ⚠️ Unmatched 'start' for Task 12 at 1406311
# ⚠️ Unmatched 'end' for Task 3 at 699751
# ⚠️ Unmatched 'end' for Task 13 at 916064
# ⚠️ Unmatched 'end' for Task 0 at 1584324
# ⚠️ Unmatched 'end' for Task 11 at 3573197
# ⚠️ Unmatched 'end' for Task 13 at 3776719
# ⚠️ Unmatched 'start' for Task 1 at 1580609
# ⚠️ Unmatched 'start' for Task 5 at 666608
# ⚠️ Unmatched 'start' for Task 10 at 3566819
# ⚠️ Unmatched 'start' for Task 12 at 3768105
# ⚠️ Unmatched 'end' for Task 5 at 2943447
# ⚠️ Unmatched 'end' for Task 8 at 3276089
# ⚠️ Unmatched 'start' for Task 1 at 1858042
# ⚠️ Unmatched 'start' for Task 1 at 1888695
# ⚠️ Unmatched 'start' for Task 1 at 1900695
# ⚠️ Unmatched 'start' for Task 1 at 2793710
# ⚠️ Unmatched 'end' for Task 6 at 1843141
# ⚠️ Unmatched 'start' for Task 3 at 1802257
# ⚠️ Unmatched 'end' for Task 1 at 458260
# ⚠️ Unmatched 'end' for Task 13 at 1458465
# ⚠️ Unmatched 'end' for Task 0 at 1334373
# ⚠️ Unmatched 'end' for Task 13 at 2699873
# ⚠️ Unmatched 'start' for Task 12 at 2685478
# ⚠️ Unmatched 'end' for Task 13 at 397140
# ⚠️ Unmatched 'end' for Task 13 at 662596
# ⚠️ Unmatched 'start' for Task 12 at 386588
# ⚠️ Unmatched 'start' for Task 12 at 651810
# ⚠️ Unmatched 'end' for Task 13 at 3150121
# ⚠️ Unmatched 'start' for Task 12 at 3141045
# ⚠️ Unmatched 'end' for Task 13 at 723306
# ⚠️ Unmatched 'end' for Task 4 at 2067341
# ⚠️ Unmatched 'start' for Task 1 at 564465
# ⚠️ Unmatched 'start' for Task 11 at 721766
# ⚠️ Unmatched 'start' for Task 3 at 2040777
# ⚠️ Unmatched 'end' for Task 12 at 927284
# Finding tasks for participant 001 Scenario 1
# ⚠️ Unmatched 'end' for Task 5 at 3459514
# ⚠️ Unmatched 'start' for Task 3 at 3443448
# Finding tasks for participant 001 Scenario 2
# ⚠️ Unmatched 'end' for Task 5 at 1475678
# Finding tasks for participant 001 Scenario 3
# Finding tasks for participant 002 Scenario 1
# ⚠️ Unmatched 'end' for Task 3 at 732128
# ⚠️ Unmatched 'end' for Task 8 at 1168579
# ⚠️ Unmatched 'end' for Task 1 at 1407071
# ⚠️ Unmatched 'start' for Task 12 at 1171948
# Finding tasks for participant 002 Scenario 2
# ⚠️ Unmatched 'end' for Task 7 at 1407679
# ⚠️ Unmatched 'end' for Task 8 at 3096761
# ⚠️ Unmatched 'end' for Task 0 at 3174255
# ⚠️ Unmatched 'start' for Task 1 at 695652
# ⚠️ Unmatched 'start' for Task 12 at 3785377
# ⚠️ Unmatched 'start' for Task 13 at 3467085
# ⚠️ Unmatched 'start' for Task 13 at 3467602
# ⚠️ Unmatched 'start' for Task 13 at 3467757
# ⚠️ Unmatched 'start' for Task 6 at 1395939
# ⚠️ Unmatched 'start' for Task 4 at 3513371
# Finding tasks for participant 002 Scenario 3
# ⚠️ Unmatched 'end' for Task 1 at 2525380
# Finding tasks for participant 003 Scenario 1
# ⚠️ Unmatched 'end' for Task 13 at 3253527
# ⚠️ Unmatched 'start' for Task 12 at 3248347
# Finding tasks for participant 003 Scenario 3
# ⚠️ Unmatched 'end' for Task 13 at 2910462
# ⚠️ Unmatched 'end' for Task 7 at 3179705
# Finding tasks for participant 004 Scenario 1
# ⚠️ Unmatched 'end' for Task 1 at 346849
# ⚠️ Unmatched 'end' for Task 12 at 815514
# ⚠️ Unmatched 'end' for Task 12 at 884947
# ⚠️ Unmatched 'end' for Task 12 at 887080
# ⚠️ Unmatched 'end' for Task 8 at 957579
# ⚠️ Unmatched 'end' for Task 13 at 1010556
# ⚠️ Unmatched 'end' for Task 13 at 1096176
# ⚠️ Unmatched 'end' for Task 13 at 1311628
# ⚠️ Unmatched 'end' for Task 13 at 1319967
# ⚠️ Unmatched 'end' for Task 8 at 1364041
# ⚠️ Unmatched 'end' for Task 12 at 1378949
# ⚠️ Unmatched 'end' for Task 13 at 1421535
# ⚠️ Unmatched 'end' for Task 13 at 1866313
# ⚠️ Unmatched 'end' for Task 13 at 1878613
# ⚠️ Unmatched 'end' for Task 13 at 1912223
# ⚠️ Unmatched 'end' for Task 13 at 1924307
# ⚠️ Unmatched 'end' for Task 13 at 2179696
# ⚠️ Unmatched 'end' for Task 13 at 2309476
# ⚠️ Unmatched 'end' for Task 3 at 2715224
# ⚠️ Unmatched 'end' for Task 13 at 2778212
# ⚠️ Unmatched 'end' for Task 13 at 2899282
# ⚠️ Unmatched 'start' for Task 13 at 3650104
# ⚠️ Unmatched 'start' for Task 6 at 1350277
# Finding tasks for participant 004 Scenario 2
# Finding tasks for participant 004 Scenario 3
# ⚠️ Unmatched 'end' for Task 5 at 357881
# ⚠️ Unmatched 'end' for Task 12 at 2140153
# ⚠️ Unmatched 'end' for Task 12 at 2152434
# ⚠️ Unmatched 'end' for Task 0 at 2546911
# Finding tasks for participant 005 Scenario 1
# Finding tasks for participant 005 Scenario 2
# ⚠️ Unmatched 'start' for Task 12 at 1035423
# ⚠️ Unmatched 'start' for Task 4 at 411413
# ⚠️ Unmatched 'start' for Task 4 at 430256
# ⚠️ Unmatched 'start' for Task 4 at 442300
# ⚠️ Unmatched 'start' for Task 13 at 1091083
# Finding tasks for participant 005 Scenario 3
# ⚠️ Unmatched 'end' for Task 10 at 1047573
# ⚠️ Unmatched 'start' for Task 10 at 1056268
# Finding tasks for participant 006 Scenario 1
# ⚠️ Unmatched 'end' for Task 7 at 3565790
# ⚠️ Unmatched 'end' for Task 10 at 3747983
# ⚠️ Unmatched 'start' for Task 11 at 3739610
# ⚠️ Unmatched 'start' for Task 6 at 3558720
# Finding tasks for participant 006 Scenario 2
# Finding tasks for participant 006 Scenario 3
# Finding tasks for participant 007 Scenario 1
# ⚠️ Unmatched 'end' for Task 1 at 942377
# ⚠️ Unmatched 'start' for Task 12 at 910932
# Finding tasks for participant 007 Scenario 2
# Finding tasks for participant 007 Scenario 3
# Finding tasks for participant 008 Scenario 1
# Finding tasks for participant 008 Scenario 2
# ⚠️ Unmatched 'end' for Task 2 at 279822
# ⚠️ Unmatched 'end' for Task 2 at 282033
# ⚠️ Unmatched 'end' for Task 4 at 995740
# ⚠️ Unmatched 'end' for Task 8 at 3031455
# ⚠️ Unmatched 'end' for Task 7 at 3125629
# ⚠️ Unmatched 'start' for Task 3 at 979539
# ⚠️ Unmatched 'start' for Task 6 at 2989803
# ⚠️ Unmatched 'start' for Task 6 at 3119534
# Finding tasks for participant 008 Scenario 3
# ⚠️ Unmatched 'end' for Task 13 at 1463675
# Finding tasks for participant 009 Scenario 1
# ⚠️ Unmatched 'end' for Task 5 at 268385
# ⚠️ Unmatched 'start' for Task 3 at 253311
# Finding tasks for participant 009 Scenario 3
# ⚠️ Unmatched 'end' for Task 8 at 346422
# ⚠️ Unmatched 'end' for Task 3 at 669788
# ⚠️ Unmatched 'end' for Task 11 at 2004437
# ⚠️ Unmatched 'start' for Task 12 at 1999080
# ⚠️ Unmatched 'start' for Task 4 at 658499
# Finding tasks for participant 010 Scenario 3
# ⚠️ Unmatched 'end' for Task 3 at 2240089
# ⚠️ Unmatched 'start' for Task 1 at 1288240
# ⚠️ Unmatched 'start' for Task 1 at 2419810
# ⚠️ Unmatched 'start' for Task 2 at 1336720
# ⚠️ Unmatched 'start' for Task 2 at 1384217
# ⚠️ Unmatched 'start' for Task 8 at 2222645
# ⚠️ Unmatched 'start' for Task 6 at 1631738
# ⚠️ Unmatched 'start' for Task 6 at 1719120
# Finding tasks for participant 011 Scenario 1
# Finding tasks for participant 011 Scenario 2
# ⚠️ Unmatched 'end' for Task 5 at 1511042
# ⚠️ Unmatched 'start' for Task 3 at 1493000
# Finding tasks for participant 011 Scenario 3
# ⚠️ Unmatched 'end' for Task 1 at 737258
# ⚠️ Unmatched 'start' for Task 0 at 721416
# Finding tasks for participant 013 Scenario 1
# Finding tasks for participant 013 Scenario 2
# ⚠️ Unmatched 'start' for Task 1 at 3897662
# Finding tasks for participant 013 Scenario 3
# ⚠️ Unmatched 'end' for Task 8 at 3014348
# Finding tasks for participant 014 Scenario 1
# ⚠️ Unmatched 'start' for Task 3 at 1759617
# Finding tasks for participant 014 Scenario 2
# Finding tasks for participant 014 Scenario 3
# ⚠️ Unmatched 'start' for Task 3 at 2434454
# ⚠️ Unmatched 'start' for Task 7 at 2328448
# Finding tasks for participant 015 Scenario 1
# ⚠️ Unmatched 'end' for Task 6 at 300941
# Finding tasks for participant 015 Scenario 2
# ⚠️ Unmatched 'start' for Task 1 at 125438
# Finding tasks for participant 015 Scenario 3
# ⚠️ Unmatched 'end' for Task 11 at 1802681
# ⚠️ Unmatched 'start' for Task 0 at 896939
# ⚠️ Unmatched 'start' for Task 5 at 3162810
# Finding tasks for participant 016 Scenario 1
# ⚠️ Unmatched 'end' for Task 8 at 3240615
# ⚠️ Unmatched 'start' for Task 5 at 3216417
# Finding tasks for participant 016 Scenario 2
# Finding tasks for participant 016 Scenario 3
# ⚠️ Unmatched 'end' for Task 6 at 1790188
# Finding tasks for participant 017 Scenario 1
# Finding tasks for participant 017 Scenario 2
# ⚠️ Unmatched 'end' for Task 1 at 670917
# ⚠️ Unmatched 'end' for Task 1 at 670917
# ⚠️ Unmatched 'end' for Task 13 at 1410331
# ⚠️ Unmatched 'start' for Task 12 at 1406311
# Finding tasks for participant 017 Scenario 3
# ⚠️ Unmatched 'end' for Task 3 at 699751
# ⚠️ Unmatched 'end' for Task 13 at 916064
# ⚠️ Unmatched 'end' for Task 0 at 1584324
# ⚠️ Unmatched 'end' for Task 11 at 3573197
# ⚠️ Unmatched 'end' for Task 13 at 3776719
# ⚠️ Unmatched 'start' for Task 1 at 1580609
# ⚠️ Unmatched 'start' for Task 5 at 666608
# ⚠️ Unmatched 'start' for Task 10 at 3566819
# ⚠️ Unmatched 'start' for Task 12 at 3768105
# Finding tasks for participant 018 Scenario 1
# ⚠️ Unmatched 'end' for Task 5 at 2943447
# ⚠️ Unmatched 'end' for Task 8 at 3276089
# ⚠️ Unmatched 'start' for Task 1 at 1858042
# ⚠️ Unmatched 'start' for Task 1 at 1888695
# ⚠️ Unmatched 'start' for Task 1 at 1900695
# ⚠️ Unmatched 'start' for Task 1 at 2793710
# Finding tasks for participant 018 Scenario 2
# ⚠️ Unmatched 'end' for Task 6 at 1843141
# ⚠️ Unmatched 'start' for Task 3 at 1802257
# Finding tasks for participant 018 Scenario 3
# Finding tasks for participant 019 Scenario 1
# ⚠️ Unmatched 'end' for Task 1 at 458260
# ⚠️ Unmatched 'end' for Task 13 at 1458465
# Finding tasks for participant 019 Scenario 2
# ⚠️ Unmatched 'end' for Task 0 at 1334373
# Finding tasks for participant 019 Scenario 3
# Finding tasks for participant 020 Scenario 1
# ⚠️ Unmatched 'end' for Task 13 at 2699873
# ⚠️ Unmatched 'start' for Task 12 at 2685478
# Finding tasks for participant 020 Scenario 2
# ⚠️ Unmatched 'end' for Task 13 at 397140
# ⚠️ Unmatched 'end' for Task 13 at 662596
# ⚠️ Unmatched 'start' for Task 12 at 386588
# ⚠️ Unmatched 'start' for Task 12 at 651810
# Finding tasks for participant 020 Scenario 3
# ⚠️ Unmatched 'end' for Task 13 at 3150121
# ⚠️ Unmatched 'start' for Task 12 at 3141045
# Finding tasks for participant 023 Scenario 1
# Finding tasks for participant 023 Scenario 2
# ⚠️ Unmatched 'end' for Task 13 at 723306
# ⚠️ Unmatched 'end' for Task 4 at 2067341
# ⚠️ Unmatched 'start' for Task 1 at 564465
# ⚠️ Unmatched 'start' for Task 11 at 721766
# ⚠️ Unmatched 'start' for Task 3 at 2040777
# Finding tasks for participant 023 Scenario 3
# ⚠️ Unmatched 'end' for Task 12 at 927284

# %%
from collections import Counter, defaultdict

keys = chunks_et.keys()

task_counts = Counter()

for k in keys:
    participant, scenario, task, occurrence = k.split("_")
    task_counts[(participant, scenario, task)] += 1

# Step 2: sum counts per (participant, scenario)
scenario_totals = defaultdict(int)

for (participant, scenario, task), count in task_counts.items():
    scenario_totals[(participant, scenario)] += count

# Step 3: compute proportions
task_proportions = {}

for (participant, scenario, task), count in task_counts.items():
    total = scenario_totals[(participant, scenario)]
    proportion = count / total
    task_proportions[(participant, scenario, task)] = proportion

# Pretty print:
for k, p in task_proportions.items():
    participant, scenario, task = k
    if task == '-1':
        print(f"Participant {participant}, Scenario {scenario}, Task {task} → proportion {p:.3f}")
# Out:
# Participant 001, Scenario 1, Task -1 → proportion 0.642
# Participant 001, Scenario 2, Task -1 → proportion 0.584
# Participant 001, Scenario 3, Task -1 → proportion 0.769
# Participant 002, Scenario 1, Task -1 → proportion 0.783
# Participant 002, Scenario 2, Task -1 → proportion 0.725
# Participant 002, Scenario 3, Task -1 → proportion 0.741
# Participant 003, Scenario 1, Task -1 → proportion 0.727
# Participant 003, Scenario 3, Task -1 → proportion 0.648
# Participant 004, Scenario 1, Task -1 → proportion 0.780
# Participant 004, Scenario 2, Task -1 → proportion 0.802
# Participant 004, Scenario 3, Task -1 → proportion 0.812
# Participant 005, Scenario 1, Task -1 → proportion 0.842
# Participant 005, Scenario 2, Task -1 → proportion 0.823
# Participant 005, Scenario 3, Task -1 → proportion 0.769
# Participant 006, Scenario 1, Task -1 → proportion 0.695
# Participant 006, Scenario 2, Task -1 → proportion 0.702
# Participant 007, Scenario 1, Task -1 → proportion 0.781
# Participant 007, Scenario 2, Task -1 → proportion 0.759
# Participant 007, Scenario 3, Task -1 → proportion 0.802
# Participant 008, Scenario 1, Task -1 → proportion 0.701
# Participant 008, Scenario 2, Task -1 → proportion 0.758
# Participant 008, Scenario 3, Task -1 → proportion 0.734
# Participant 009, Scenario 1, Task -1 → proportion 0.747
# Participant 009, Scenario 3, Task -1 → proportion 0.657
# Participant 010, Scenario 3, Task -1 → proportion 0.719
# Participant 011, Scenario 1, Task -1 → proportion 0.566
# Participant 011, Scenario 2, Task -1 → proportion 0.523
# Participant 011, Scenario 3, Task -1 → proportion 0.587
# Participant 013, Scenario 1, Task -1 → proportion 0.696
# Participant 013, Scenario 2, Task -1 → proportion 0.630
# Participant 013, Scenario 3, Task -1 → proportion 0.640
# Participant 014, Scenario 1, Task -1 → proportion 0.766
# Participant 014, Scenario 2, Task -1 → proportion 0.780
# Participant 014, Scenario 3, Task -1 → proportion 0.770
# Participant 015, Scenario 1, Task -1 → proportion 0.598
# Participant 015, Scenario 2, Task -1 → proportion 0.560
# Participant 015, Scenario 3, Task -1 → proportion 0.578
# Participant 016, Scenario 1, Task -1 → proportion 0.620
# Participant 016, Scenario 2, Task -1 → proportion 0.675
# Participant 016, Scenario 3, Task -1 → proportion 0.665
# Participant 017, Scenario 1, Task -1 → proportion 0.688
# Participant 017, Scenario 2, Task -1 → proportion 0.693
# Participant 017, Scenario 3, Task -1 → proportion 0.667
# Participant 018, Scenario 1, Task -1 → proportion 0.759
# Participant 018, Scenario 2, Task -1 → proportion 0.691
# Participant 018, Scenario 3, Task -1 → proportion 0.677
# Participant 019, Scenario 1, Task -1 → proportion 0.637
# Participant 019, Scenario 2, Task -1 → proportion 0.564
# Participant 019, Scenario 3, Task -1 → proportion 0.630
# Participant 020, Scenario 1, Task -1 → proportion 0.649
# Participant 020, Scenario 2, Task -1 → proportion 0.584
# Participant 020, Scenario 3, Task -1 → proportion 0.661
# Participant 023, Scenario 1, Task -1 → proportion 0.846
# Participant 023, Scenario 2, Task -1 → proportion 0.836
# Participant 023, Scenario 3, Task -1 → proportion 0.873

# %%
from collections import Counter

print("Number of total occurences per task: ")
task_window_counts = Counter(int(key.split('_')[2]) for key in chunks_et.keys())
for task_id in sorted(task_window_counts):
    print(f"Task {task_id}: {task_window_counts[task_id]} windows")
# Out:
# Number of total occurences per task:
# Task -1: 47080 windows
# Task 0: 1457 windows
# Task 1: 4432 windows
# Task 2: 1041 windows
# Task 3: 202 windows
# Task 4: 148 windows
# Task 5: 1613 windows
# Task 6: 351 windows
# Task 7: 50 windows
# Task 8: 1111 windows
# Task 9: 260 windows
# Task 10: 858 windows
# Task 11: 1456 windows
# Task 12: 4577 windows
# Task 13: 2481 windows

# %%
import importlib
import utils.helper
importlib.reload(utils.helper)
from utils.helper import drop_chunks_with_nan_et

print(len(chunks_et))

cleaned_chunks_et = drop_chunks_with_nan_et(chunks_et, threshold=0.8)
# Out:
# 67117
# Dropped 4781 multi-scale samples due to a proportion of Nans greater than 0.8 in eye-tracking window(s): ['001_1_-1_13', '001_1_-1_14', '001_1_-1_15', '001_1_-1_16', '001_1_-1_17', '001_1_-1_18', '001_1_-1_19', '001_1_-1_20', '001_1_-1_21', '001_1_-1_22'] ...

# %%
print("Number of total occurences per task: ")
task_window_counts = Counter(int(key.split('_')[2]) for key in cleaned_chunks_et.keys())
for task_id in sorted(task_window_counts):
    print(f"Task {task_id}: {task_window_counts[task_id]} windows")
# Out:
# Number of total occurences per task:
# Task -1: 43708 windows
# Task 0: 1405 windows
# Task 1: 4143 windows
# Task 2: 964 windows
# Task 3: 175 windows
# Task 4: 134 windows
# Task 5: 1377 windows
# Task 6: 320 windows
# Task 7: 46 windows
# Task 8: 990 windows
# Task 9: 241 windows
# Task 10: 826 windows
# Task 11: 1416 windows
# Task 12: 4167 windows
# Task 13: 2424 windows

# %% [markdown]
# ****
# # Feature extraction
# ****

# %%
import utils.data_processing_gaze_data
import utils.data_processing_mouse_data
import utils.data_processing_asd_events
importlib.reload(utils.data_processing_gaze_data)
importlib.reload(utils.data_processing_mouse_data)
importlib.reload(utils.data_processing_asd_events)

from utils.helper import load_asd_scenario_data
from utils.data_processing_gaze_data import GazeMetricsProcessor
from utils.data_processing_mouse_data import MouseMetricsProcessor
from utils.data_processing_asd_events import ASDEventsMetricsProcessor
import pandas as pd
from tqdm import tqdm

# ~2h30

asd_scenarios = load_asd_scenario_data(root_dir=store_dir)

prepared_asd = {}
for key, df_sc in asd_scenarios.items():
    asd = df_sc.sort_values("epoch_ms").set_index("epoch_ms")
    prepared_asd[key] = asd

window_keys = ("short", "mid", "long")
rows = []
i = 0

for uid, windows in tqdm(cleaned_chunks_et.items()):

    row = {"id": uid}
    row["participant_id"] = windows["short"]["Participant name"].iloc[0]
    row["Task_id"] = windows["short"]["Task_id"].iloc[0]
    
    p_s_id = "_".join(uid.split("_")[:2])
    scenario_asd = prepared_asd.get(p_s_id)
    if scenario_asd is None:
        continue

    for wname in window_keys:
        chunk = windows[wname]
        min_epoch = chunk["epoch_ms"].min()
        max_epoch = chunk["epoch_ms"].max()
        # fast time slice thanks to index on epoch_ms
        window_asd = scenario_asd.loc[min_epoch:max_epoch].reset_index()
        
        # Gaze metrics
        gaze_processor = GazeMetricsProcessor(chunk, timestamp_unit="ms")
        gaze_metrics = gaze_processor.compute_all_metrics()   
        prefixed_gaze = {f"{wname}_{k}": v for k, v in gaze_metrics.items()}
        row.update(prefixed_gaze)
        
        # Mouse metrics
        mouse_processor = MouseMetricsProcessor(window_asd, resample=False)
        mouse_metrics = mouse_processor.compute_all_metrics()   
        prefixed_mouse = {f"{wname}_{k}": v for k, v in mouse_metrics.items()}
        row.update(prefixed_mouse)
        
        # ASD events metrics
        asd_processor = ASDEventsMetricsProcessor(window_asd)
        asd_metrics = asd_processor.compute_all_metrics()   
        prefixed_asd = {f"{wname}_{k}": v.iat[0] for k, v in asd_metrics.items()}
        row.update(prefixed_asd)

    rows.append(row)
    i += 1
    if i == 10000:
        break
    
metrics_df = pd.DataFrame(rows)
# Out:
#  16%|█▌        | 9999/62336 [24:03<2:05:56,  6.93it/s]

# %% [markdown]
# # TS Fresh

# %%
import trainings._02_xgboost_hierarchical_training
importlib.reload(trainings._02_xgboost_hierarchical_training)
from trainings._02_xgboost_hierarchical_training import extract_tsfresh_features_from_multiscale_chunks

# 20 mins

tsfresh_data = extract_tsfresh_features_from_multiscale_chunks(
        cleaned_chunks_et, 
        ['Gaze point X [DACS px]', 'Gaze point Y [DACS px]'], 
        pval_threshold=0.05, 
        n_jobs=50)
# Out:
# Extracting TSFresh features...
# Feature Extraction: 100%|██████████| 250/250 [00:39<00:00,  6.27it/s]
# Extracting TSFresh features...
# Feature Extraction: 100%|██████████| 250/250 [00:37<00:00,  6.65it/s]
# Extracting TSFresh features...
# Feature Extraction: 100%|██████████| 250/250 [00:56<00:00,  4.41it/s]

# %%
xgboost_data = metrics_df.merge(tsfresh_data, on="id", how="inner")
xgboost_data
# Out:
#                 id participant_id  Task_id  short_Fixation Count  \
# 0       001_1_-1_0            001       -1                    13
# 1       001_1_-1_1            001       -1                    17
# 2       001_1_-1_2            001       -1                    18
# 3       001_1_-1_3            001       -1                    10
# 4       001_1_-1_4            001       -1                     8
# ...            ...            ...      ...                   ...
# 9995  004_1_-1_719            004       -1                     3
# 9996   004_1_12_42            004       12                     5
# 9997  004_1_-1_720            004       -1                     3
# 9998  004_1_-1_721            004       -1                     5
# 9999  004_1_-1_722            004       -1                     5
#
#       short_Total Fixation Duration (s)  short_Avg Fixation Duration (s)  \
# 0                                 3.784                         0.291077
# 1                                 4.415                         0.259706
# 2                                 4.142                         0.230111
# 3                                 4.232                         0.423200
# 4                                 2.715                         0.339375
# ...                                 ...                              ...
# 9995                              2.508                         0.836000
# 9996                              3.123                         0.624600
# 9997                              4.641                         1.547000
# 9998                              4.533                         0.906600
# 9999                              4.815                         0.963000
#
#       short_Saccade Count  short_Avg Saccade Amplitude (px)  \
# 0                      48                        122.385408
# 1                      46                        103.709524
# 2                      46                        107.551738
# 3                      25                        107.973174
# 4                      18                        131.851105
# ...                   ...                               ...
# 9995                    3                         77.118507
# 9996                   21                        269.994729
# 9997                   17                        256.284176
# 9998                   12                        118.593590
# 9999                    9                        114.084778
#
#       short_Avg Saccade Velocity (px/s)  short_Avg Gaze Velocity (px/s)  ...  \
# 0                          14717.509438                     1758.013579  ...
# 1                          12525.211390                     1699.833873  ...
# 2                          13021.663369                     1852.512615  ...
# 3                          12993.801937                     1348.387791  ...
# 4                          15933.778276                      956.915427  ...
# ...                                 ...                             ...  ...
# 9995                        9243.580881                      291.685870  ...
# 9996                       32533.202835                     1265.580060  ...
# 9997                       31111.362248                     1273.070339  ...
# 9998                       14094.333843                      873.121744  ...
# 9999                       13558.614208                      819.286900  ...
#
#       long_Gaze point X [DACS px]__mean  \
# 0                            725.359487
# 1                            825.513107
# 2                           1101.328501
# 3                           1164.679189
# 4                           1154.649485
# ...                                 ...
# 9995                         824.291331
# 9996                         852.442639
# 9997                         874.477055
# 9998                         867.415870
# 9999                         876.844437
#
#       long_Gaze point X [DACS px]__sum_values  \
# 0                                   2320425.0
# 1                                   2582205.0
# 2                                   3342532.0
# 3                                   3503355.0
# 4                                   3472031.0
# ...                                       ...
# 9995                                2557776.0
# 9996                                2674965.0
# 9997                                2744109.0
# 9998                                2721951.0
# 9999                                2750661.0
#
#       long_Gaze point X [DACS px]__absolute_maximum  \
# 0                                            2057.0
# 1                                            2057.0
# 2                                            2057.0
# 3                                            2057.0
# 4                                            2057.0
# ...                                             ...
# 9995                                         1381.0
# 9996                                         1510.0
# 9997                                         1510.0
# 9998                                         1510.0
# 9999                                         1510.0
#
#       long_Gaze point Y [DACS px]__mean  long_Gaze point X [DACS px]__maximum  \
# 0                            806.727727                                2057.0
# 1                            774.083440                                2057.0
# 2                            601.314662                                2057.0
# 3                            612.753989                                2057.0
# 4                            675.059195                                2057.0
# ...                                 ...                                   ...
# 9995                         642.872059                                1381.0
# 9996                         644.019439                                1510.0
# 9997                         628.441364                                1510.0
# 9998                         621.753346                                1510.0
# 9999                         623.036659                                1510.0
#
#       long_Gaze point Y [DACS px]__sum_values  \
# 0                                   2580722.0
# 1                                   2421333.0
# 2                                   1824990.0
# 3                                   1843164.0
# 4                                   2029903.0
# ...                                       ...
# 9995                                1994832.0
# 9996                                2020933.0
# 9997                                1972049.0
# 9998                                1951062.0
# 9999                                1954466.0
#
#       long_Gaze point Y [DACS px]__standard_deviation  \
# 0                                          395.005788
# 1                                          389.472247
# 2                                          307.172021
# 3                                          311.393455
# 4                                          324.868404
# ...                                               ...
# 9995                                       155.327585
# 9996                                       159.616701
# 9997                                       143.129931
# 9998                                       149.102641
# 9999                                       150.263149
#
#       long_Gaze point Y [DACS px]__variance  \
# 0                             156029.572945
# 1                             151688.630826
# 2                              94354.650576
# 3                              96965.883628
# 4                             105539.479702
# ...                                     ...
# 9995                           24126.658784
# 9996                           25477.491337
# 9997                           20486.177091
# 9998                           22231.597543
# 9999                           22579.013957
#
#       long_Gaze point X [DACS px]__root_mean_square  \
# 0                                       1127.259914
# 1                                       1121.652692
# 2                                       1204.952224
# 3                                       1249.838991
# 4                                       1245.739248
# ...                                             ...
# 9995                                     834.419925
# 9996                                     864.659388
# 9997                                     884.481787
# 9998                                     878.166995
# 9999                                     886.928093
#
#       long_Gaze point Y [DACS px]__median
# 0                                   861.0
# 1                                   854.0
# 2                                   592.0
# 3                                   641.0
# 4                                   659.0
# ...                                   ...
# 9995                                678.0
# 9996                                677.0
# 9997                                673.0
# 9998                                671.0
# 9999                                670.0
#
# [10000 rows x 462 columns]

# %% [markdown]
# ****
# # Training set
# ****

# %%
from trainings._02_xgboost_hierarchical_training import split_by_participant

train_df, val_df, test_df, parts = split_by_participant(xgboost_data, group_col="participant_id",
                                                    test_size=0.2, val_size=0.1, random_state=42)
