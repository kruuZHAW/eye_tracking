# %%
import os, sqlite3
import pandas as pd
import numpy as np
from zoneinfo import ZoneInfo
from google.protobuf.json_format import MessageToDict
# import sys; sys.path.insert(0, "gen")
from gen import messages_pb2  # generated by setup.sh

# %% [markdown]
# # Eye-Tracking

# %%
data_path = "/store/kruu/eye_tracking/training_data/010/Scenario 3/ET/010_scenario_3_gaze_data_fusion.tsv"
df_eye_tracking = pd.read_csv(data_path, sep="\t")
# Out:
# /tmp/ipykernel_2332049/2446824208.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_eye_tracking = pd.read_csv(data_path, sep="\t")

# %%
def slice_between_events(df, start="ScreenRecordingStart", end="ScreenRecordingEnd", *, include_bounds=False):
    s = df["Event"]

    starts = np.flatnonzero(s.eq(start))
    ends   = np.flatnonzero(s.eq(end))

    if len(starts) != 1 or len(ends) != 1:
        raise ValueError(f"Expected exactly one '{start}' and one '{end}' "
                         f"(got {len(starts)} and {len(ends)}).")
    i, j = int(starts[0]), int(ends[0])
    if j <= i:
        raise ValueError(f"'{end}' occurs before '{start}' (positions {j} <= {i}).")

    if include_bounds:
        return df.iloc[i:j+1]     # includes the start & end rows
    else:
        return df.iloc[i+1:j]     # strictly between them
    
df_eye_tracking_sliced = slice_between_events(df_eye_tracking, include_bounds=False)
df_eye_tracking_sliced = df_eye_tracking_sliced.drop(columns=["Mouse position X [DACS px]", "Mouse position Y [DACS px]"])

# %%
TZ = ZoneInfo("Europe/Zagreb")

date_str = df_eye_tracking_sliced["Recording date"].astype(str).str.replace(r"\.$", "", regex=True)
base_start = pd.to_datetime(
        date_str + " " + df_eye_tracking_sliced["Recording start time"].astype(str),
        format="%d.%m.%Y %H:%M:%S.%f",
        errors="coerce",
    ).dt.tz_localize(TZ, ambiguous="infer", nonexistent="shift_forward")

offset = pd.to_timedelta(pd.to_numeric(df_eye_tracking_sliced["Recording timestamp [ms]"], errors="coerce"), unit="ms")

df_eye_tracking_sliced["epoch_ms"] = (
    (base_start + offset)
      .dt.tz_convert("UTC")
      .dt.tz_localize(None)
      .astype("int64") // 1_000_000
    ).astype("Int64")

# %%
df_eye_tracking_sliced
# Out:
#         Recording timestamp [ms]  Computer timestamp [ms]       Sensor  \
# 28349                     217103                 26496749          NaN
# 28350                     217105                 26496752  Eye Tracker
# 28351                     217114                 26496760  Eye Tracker
# 28352                     217122                 26496768  Eye Tracker
# 28353                     217130                 26496777  Eye Tracker
# ...                          ...                      ...          ...
# 468298                   3860648                 30140294  Eye Tracker
# 468299                   3860650                 30140297        Mouse
# 468300                   3860656                 30140303  Eye Tracker
# 468301                   3860665                 30140311  Eye Tracker
# 468302                   3860665                 30140312          NaN
#
#         Participant name Recording date Recording start time Timeline name  \
# 28349                 10      4.9.2025.         15:53:24.795     Timeline1
# 28350                 10      4.9.2025.         15:53:24.795     Timeline1
# 28351                 10      4.9.2025.         15:53:24.795     Timeline1
# 28352                 10      4.9.2025.         15:53:24.795     Timeline1
# 28353                 10      4.9.2025.         15:53:24.795     Timeline1
# ...                  ...            ...                  ...           ...
# 468298                10      4.9.2025.         15:53:24.795     Timeline1
# 468299                10      4.9.2025.         15:53:24.795     Timeline1
# 468300                10      4.9.2025.         15:53:24.795     Timeline1
# 468301                10      4.9.2025.         15:53:24.795     Timeline1
# 468302                10      4.9.2025.         15:53:24.795     Timeline1
#
#                        Event       Event value  Gaze point X [DACS px]  ...  \
# 28349   ScreenRecordingStart  Screen Recording                     NaN  ...
# 28350                    NaN               NaN                     NaN  ...
# 28351                    NaN               NaN                     NaN  ...
# 28352                    NaN               NaN                     NaN  ...
# 28353                    NaN               NaN                     NaN  ...
# ...                      ...               ...                     ...  ...
# 468298                   NaN               NaN                     NaN  ...
# 468299                   NaN               NaN                     NaN  ...
# 468300                   NaN               NaN                     NaN  ...
# 468301                   NaN               NaN                     NaN  ...
# 468302    ScreenRecordingEnd  Screen Recording                     NaN  ...
#
#         Eye openness filtered [mm]  Gaze point left X [DACS mm]  \
# 28349                          NaN                          NaN
# 28350                          NaN                          NaN
# 28351                          NaN                          NaN
# 28352                          NaN                          NaN
# 28353                          NaN                          NaN
# ...                            ...                          ...
# 468298                         NaN                          NaN
# 468299                         NaN                          NaN
# 468300                         NaN                          NaN
# 468301                         NaN                          NaN
# 468302                         NaN                          NaN
#
#         Gaze point left Y [DACS mm]  Gaze point right X [DACS mm]  \
# 28349                           NaN                           NaN
# 28350                           NaN                           NaN
# 28351                           NaN                           NaN
# 28352                           NaN                           NaN
# 28353                           NaN                           NaN
# ...                             ...                           ...
# 468298                          NaN                           NaN
# 468299                          NaN                           NaN
# 468300                          NaN                           NaN
# 468301                          NaN                           NaN
# 468302                          NaN                           NaN
#
#         Gaze point right Y [DACS mm] Eye movement type  \
# 28349                            NaN      EyesNotFound
# 28350                            NaN      EyesNotFound
# 28351                            NaN      EyesNotFound
# 28352                            NaN      EyesNotFound
# 28353                            NaN      EyesNotFound
# ...                              ...               ...
# 468298                           NaN      EyesNotFound
# 468299                           NaN      EyesNotFound
# 468300                           NaN      EyesNotFound
# 468301                           NaN      EyesNotFound
# 468302                           NaN      EyesNotFound
#
#        Eye movement event duration [ms] Fixation point X [DACS px]  \
# 28349                            4233.0                        NaN
# 28350                            4233.0                        NaN
# 28351                            4233.0                        NaN
# 28352                            4233.0                        NaN
# 28353                            4233.0                        NaN
# ...                                 ...                        ...
# 468298                            962.0                        NaN
# 468299                            962.0                        NaN
# 468300                            962.0                        NaN
# 468301                            962.0                        NaN
# 468302                            962.0                        NaN
#
#        Fixation point Y [DACS px]       epoch_ms
# 28349                         NaN  1756994221898
# 28350                         NaN  1756994221900
# 28351                         NaN  1756994221909
# 28352                         NaN  1756994221917
# 28353                         NaN  1756994221925
# ...                           ...            ...
# 468298                        NaN  1756997865443
# 468299                        NaN  1756997865445
# 468300                        NaN  1756997865451
# 468301                        NaN  1756997865460
# 468302                        NaN  1756997865460
#
# [439954 rows x 36 columns]

# %% [markdown]
# # Events db for mouse tracking

# %%
from gen import messages_pb2
from google.protobuf.descriptor import FieldDescriptor as FD

# Map numeric types to readable names
TYPE = {getattr(FD, n): n.replace("TYPE_","").lower() for n in dir(FD) if n.startswith("TYPE_")}

def describe(desc, prefix=""):
    # fields
    for f in desc.fields:
        card = {FD.LABEL_OPTIONAL:"", FD.LABEL_REQUIRED:"required ", FD.LABEL_REPEATED:"repeated "}[f.label]
        if f.type == FD.TYPE_MESSAGE:
            print(f"{prefix}{f.name}: {card}message")
            describe(f.message_type, prefix=f"{prefix}{f.name}.")
        else:
            print(f"{prefix}{f.name}: {card}{TYPE[f.type]}")
    # oneofs
    for o in desc.oneofs:
        print(f"{prefix}(oneof) {o.name}: " + ", ".join(f.name for f in o.fields))

# Top-level Event payload schema
describe(messages_pb2.Event.DESCRIPTOR)

# Quick & dirty: just top-level field names
print([f.name for f in messages_pb2.Event.DESCRIPTOR.fields])
# Out:
# timestamp: message
# timestamp.seconds: int64
# timestamp.nanos: int32
# track: message
# track.track_number: uint32
# track.target_identification: string
# track.position: message
# track.position.lat_deg: double
# track.position.lon_deg: double
# track.velocity: message
# track.velocity.Vx_ms: double
# track.velocity.Vy_ms: double
# track.call_sign: string
# track.flight_level_m: double
# track.calculated_altitude_m: double
# track.calculated_rate_of_climb_ftmin: double
# flight_plan: message
# flight_plan.uuid: string
# flight_plan.fixm: string
# trajectory: message
# trajectory.flight_plan_uuid: string
# trajectory.points: repeated message
# trajectory.points.lat_deg: double
# trajectory.points.lon_deg: double
# trajectory.points.altitude_m: double
# trajectory.points.flight_level: double
# trajectory.points.ground_speed_ms: double
# trajectory.points.indicated_airspeed_ms: double
# trajectory.points.true_airspeed_ms: double
# trajectory.points.mach: double
# trajectory.points.true_heading: double
# trajectory.points.vertical_rate: double
# trajectory.points.altitude_ft: double
# trajectory.points.(oneof) vertical: altitude_m, flight_level
# trajectory.points.(oneof) speed_variant: ground_speed_ms, indicated_airspeed_ms, true_airspeed_ms, mach
# asd_event: message
# asd_event.timestamp: message
# asd_event.timestamp.seconds: int64
# asd_event.timestamp.nanos: int32
# asd_event.mouse_position: message
# asd_event.mouse_position.x: int32
# asd_event.mouse_position.y: int32
# asd_event.track_label_position: message
# asd_event.track_label_position.track_number: uint32
# asd_event.track_label_position.x: int32
# asd_event.track_label_position.y: int32
# asd_event.track_label_position.width: int32
# asd_event.track_label_position.height: int32
# asd_event.track_label_position.visible: bool
# asd_event.track_label_position.hovered: bool
# asd_event.track_label_position.selected: bool
# asd_event.track_label_position.on_pip: bool
# asd_event.track_label_position.flight_id: message
# asd_event.track_label_position.flight_id.uuid: string
# asd_event.track_label_position.flight_id.track_number: uint32
# asd_event.track_label_position.flight_id.callsign: string
# asd_event.track_screen_position: message
# asd_event.track_screen_position.track_number: uint32
# asd_event.track_screen_position.x: int32
# asd_event.track_screen_position.y: int32
# asd_event.track_screen_position.visible: bool
# asd_event.track_screen_position.flight_id: message
# asd_event.track_screen_position.flight_id.uuid: string
# asd_event.track_screen_position.flight_id.track_number: uint32
# asd_event.track_screen_position.flight_id.callsign: string
# asd_event.clearance: message
# asd_event.clearance.track_number: uint32
# asd_event.clearance.clearance_type: string
# asd_event.clearance.clearance: string
# asd_event.clearance.flight_id: message
# asd_event.clearance.flight_id.uuid: string
# asd_event.clearance.flight_id.track_number: uint32
# asd_event.clearance.flight_id.callsign: string
# asd_event.popup: message
# asd_event.popup.track_number: uint32
# asd_event.popup.name: string
# asd_event.popup.opened: bool
# asd_event.popup.flight_id: message
# asd_event.popup.flight_id.uuid: string
# asd_event.popup.flight_id.track_number: uint32
# asd_event.popup.flight_id.callsign: string
# asd_event.transfer: message
# asd_event.transfer.track_number: uint32
# asd_event.transfer.transfer_type: enum
# asd_event.transfer.flight_id: message
# asd_event.transfer.flight_id.uuid: string
# asd_event.transfer.flight_id.track_number: uint32
# asd_event.transfer.flight_id.callsign: string
# asd_event.sep_tool: message
# asd_event.sep_tool.opened: message
# asd_event.sep_tool.opened.track_number: uint32
# asd_event.sep_tool.opened.flight_id: message
# asd_event.sep_tool.opened.flight_id.uuid: string
# asd_event.sep_tool.opened.flight_id.track_number: uint32
# asd_event.sep_tool.opened.flight_id.callsign: string
# asd_event.sep_tool.connected: message
# asd_event.sep_tool.connected.track_number_1: uint32
# asd_event.sep_tool.connected.track_number_2: uint32
# asd_event.sep_tool.connected.flight_id_1: message
# asd_event.sep_tool.connected.flight_id_1.uuid: string
# asd_event.sep_tool.connected.flight_id_1.track_number: uint32
# asd_event.sep_tool.connected.flight_id_1.callsign: string
# asd_event.sep_tool.connected.flight_id_2: message
# asd_event.sep_tool.connected.flight_id_2.uuid: string
# asd_event.sep_tool.connected.flight_id_2.track_number: uint32
# asd_event.sep_tool.connected.flight_id_2.callsign: string
# asd_event.sep_tool.closed: bool
# asd_event.sep_tool.type: enum
# asd_event.sep_tool.measurement_id: uint32
# asd_event.sep_tool.(oneof) state: opened, connected, closed
# asd_event.distance_measurement: message
# asd_event.distance_measurement.added: message
# asd_event.distance_measurement.added.measurement_id: uint32
# asd_event.distance_measurement.added.first: message
# asd_event.distance_measurement.added.first.track_number: uint32
# asd_event.distance_measurement.added.first.lat_lon: message
# asd_event.distance_measurement.added.first.lat_lon.lat_deg: double
# asd_event.distance_measurement.added.first.lat_lon.lon_deg: double
# asd_event.distance_measurement.added.first.flight_id: message
# asd_event.distance_measurement.added.first.flight_id.uuid: string
# asd_event.distance_measurement.added.first.flight_id.track_number: uint32
# asd_event.distance_measurement.added.first.flight_id.callsign: string
# asd_event.distance_measurement.added.first.(oneof) kind: lat_lon, flight_id
# asd_event.distance_measurement.added.second: message
# asd_event.distance_measurement.added.second.track_number: uint32
# asd_event.distance_measurement.added.second.lat_lon: message
# asd_event.distance_measurement.added.second.lat_lon.lat_deg: double
# asd_event.distance_measurement.added.second.lat_lon.lon_deg: double
# asd_event.distance_measurement.added.second.flight_id: message
# asd_event.distance_measurement.added.second.flight_id.uuid: string
# asd_event.distance_measurement.added.second.flight_id.track_number: uint32
# asd_event.distance_measurement.added.second.flight_id.callsign: string
# asd_event.distance_measurement.added.second.(oneof) kind: lat_lon, flight_id
# asd_event.distance_measurement.removed: message
# asd_event.distance_measurement.removed.measurement_id: uint32
# asd_event.distance_measurement.position_updated: message
# asd_event.distance_measurement.position_updated.measurement_id: uint32
# asd_event.distance_measurement.position_updated.start: message
# asd_event.distance_measurement.position_updated.start.x: int32
# asd_event.distance_measurement.position_updated.start.y: int32
# asd_event.distance_measurement.position_updated.end: message
# asd_event.distance_measurement.position_updated.end.x: int32
# asd_event.distance_measurement.position_updated.end.y: int32
# asd_event.distance_measurement.(oneof) change: added, removed, position_updated
# asd_event.speed_vector: message
# asd_event.speed_vector.mode_updated: message
# asd_event.speed_vector.mode_updated.mode: enum
# asd_event.speed_vector.visibility: message
# asd_event.speed_vector.visibility.track_number: uint32
# asd_event.speed_vector.visibility.visible: bool
# asd_event.speed_vector.visibility.flight_id: message
# asd_event.speed_vector.visibility.flight_id.uuid: string
# asd_event.speed_vector.visibility.flight_id.track_number: uint32
# asd_event.speed_vector.visibility.flight_id.callsign: string
# asd_event.speed_vector.length: message
# asd_event.speed_vector.length.length_seconds: int32
# asd_event.speed_vector.(oneof) update: mode_updated, visibility, length
# asd_event.track_mark: message
# asd_event.track_mark.track_number: uint32
# asd_event.track_mark.mark_type: enum
# asd_event.track_mark.mark_variant: enum
# asd_event.track_mark.mark_scope: string
# asd_event.track_mark.mark_set: bool
# asd_event.track_mark.flight_id: message
# asd_event.track_mark.flight_id.uuid: string
# asd_event.track_mark.flight_id.track_number: uint32
# asd_event.track_mark.flight_id.callsign: string
# asd_event.route_interaction: message
# asd_event.route_interaction.flight_id: message
# asd_event.route_interaction.flight_id.uuid: string
# asd_event.route_interaction.flight_id.track_number: uint32
# asd_event.route_interaction.flight_id.callsign: string
# asd_event.route_interaction.action_type: enum
# asd_event.route_interaction.value: string
# asd_event.keyboard_shortcut: message
# asd_event.keyboard_shortcut.action_name: string
# asd_event.(oneof) event: mouse_position, track_label_position, track_screen_position, clearance, popup, transfer, sep_tool, distance_measurement, speed_vector, track_mark, route_interaction, keyboard_shortcut
# alert: message
# alert.message_type: enum
# alert.alert_status: enum
# alert.track_number_1: uint32
# alert.track_number_2: uint32
# alert.alert_id: uint32
# safetynet_volume: message
# safetynet_volume.safety_net_volume_unique_id: string
# safetynet_volume.type: enum
# safetynet_volume.activeation_status: enum
# safetynet_volume.current_status: enum
# asterix: bytes
# flight_record_report_stream: message
# flight_record_report_stream.batch_event: enum
# flight_record_report_stream.flight_record_update: message
# flight_record_report_stream.flight_record_update.flight_record: message
# flight_record_report_stream.flight_record_update.flight_record.flight_record_id: string
# flight_record_report_stream.flight_record_update.flight_record.version: uint32
# flight_record_report_stream.flight_record_update.flight_record.aircraft_identification: message
# flight_record_report_stream.flight_record_update.flight_record.aircraft_identification.value: string
# flight_record_report_stream.flight_record_update.flight_record.aircraft_address: message
# flight_record_report_stream.flight_record_update.flight_record.aircraft_address.value: fixed32
# flight_record_report_stream.flight_record_update.flight_record.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.current_flight_rules: enum
# flight_record_report_stream.flight_record_update.flight_record.type_of_flight: enum
# flight_record_report_stream.flight_record_update.flight_record.number_of_aircraft: message
# flight_record_report_stream.flight_record_update.flight_record.number_of_aircraft.number_of_aircraft: uint32
# flight_record_report_stream.flight_record_update.flight_record.aircraft_type_and_wake_turbulence_category: message
# flight_record_report_stream.flight_record_update.flight_record.aircraft_type_and_wake_turbulence_category.aircraft_type: string
# flight_record_report_stream.flight_record_update.flight_record.aircraft_type_and_wake_turbulence_category.wake_turbulence_category: enum
# flight_record_report_stream.flight_record_update.flight_record.aircraft_type_and_wake_turbulence_category.aircraft_performance_category: enum
# flight_record_report_stream.flight_record_update.flight_record.communication_and_navigation_capabilities: message
# flight_record_report_stream.flight_record_update.flight_record.communication_and_navigation_capabilities.hasStandardCapabilities: bool
# flight_record_report_stream.flight_record_update.flight_record.communication_and_navigation_capabilities.otherCommunicationCapabilities: string
# flight_record_report_stream.flight_record_update.flight_record.communication_and_navigation_capabilities.otherDatalinkCapabilities: string
# flight_record_report_stream.flight_record_update.flight_record.communication_and_navigation_capabilities.otherNavigationalCapabilities: string
# flight_record_report_stream.flight_record_update.flight_record.communication_and_navigation_capabilities.communicationCapabilities: repeated enum
# flight_record_report_stream.flight_record_update.flight_record.communication_and_navigation_capabilities.datalinkCommunicationCapabilities: repeated enum
# flight_record_report_stream.flight_record_update.flight_record.communication_and_navigation_capabilities.navigationalCapabilities: repeated enum
# flight_record_report_stream.flight_record_update.flight_record.communication_and_navigation_capabilities.performanceBasedNavigationCapabilities: repeated enum
# flight_record_report_stream.flight_record_update.flight_record.surveillance_capabilities: message
# flight_record_report_stream.flight_record_update.flight_record.surveillance_capabilities.codes: repeated enum
# flight_record_report_stream.flight_record_update.flight_record.surveillance_capabilities.additional_surveillance_capabilities: string
# flight_record_report_stream.flight_record_update.flight_record.planned_departure_aerodrome_and_time: message
# flight_record_report_stream.flight_record_update.flight_record.planned_departure_aerodrome_and_time.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_departure_aerodrome_and_time.item18_departure_information: string
# flight_record_report_stream.flight_record_update.flight_record.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements: repeated message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_point_or_navaid.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_route: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designated_route.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_designator.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.latlon: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.latlon.latitude: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.latlon.latitude.degrees: double
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.latlon.longitude: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.latlon.longitude.degrees: double
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_position_point.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_designated_point_or_navaid.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.latlon: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.latlon.latitude: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.latlon.latitude.degrees: double
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.latlon.longitude: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.latlon.longitude.degrees: double
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.planned_position_point.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.distance: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.distance.metres: double
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.magnetic_bearing: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.magnetic_bearing.degrees: double
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_relative_point.(oneof) reference_point: planned_designated_point_or_navaid, planned_position_point
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_sid: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_sid.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_star: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_star.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_departure_aerodrome: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_departure_aerodrome.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_departure_aerodrome.item18_departure_information: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_destination_aerodrome: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_destination_aerodrome.code: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_destination_aerodrome.item18_destination_information: string
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_indicator: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_indicator.type: enum
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_indicator.sequence_number: uint32
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_indicator.duration: message
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.planned_indicator.duration.milliseconds: sfixed64
# flight_record_report_stream.flight_record_update.flight_record.planned_route_elements.(oneof) variants: planned_designated_point_or_navaid, planned_designated_route, planned_designator, planned_position_point, planned_relative_point, planned_sid, planned_star, planned_departure_aerodrome, planned_destination_aerodrome, planned_indicator
# flight_record_report_stream.flight_record_update.flight_record.planned_destination_aerodrome_and_total_estimated_elapsed_time: message
# flight_record_report_stream.flight_record_update.flight_record.planned_destination_aerodrome_and_total_estimated_elapsed_time.code: string
# flight_record_report_stream.flight_record_update.flight_record.planned_destination_aerodrome_and_total_estimated_elapsed_time.item18_destination_information: string
# flight_record_report_stream.flight_record_update.flight_record.planned_destination_alternate_aerodromes: repeated message
# flight_record_report_stream.flight_record_update.flight_record.planned_destination_alternate_aerodromes.designator: string
# flight_record_report_stream.flight_record_update.flight_record.planned_destination_alternate_aerodromes.item18_alternate_destination_information: string
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record: message
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.state: enum
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.exit_fir: string
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.assigned_ssr_code: message
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.assigned_ssr_code.code: uint32
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.previously_assigned_ssr_code: message
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.previously_assigned_ssr_code.code: uint32
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.system_previous_ssr_code: message
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.system_previous_ssr_code.code: uint32
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.assigned_mode_a_code: message
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.assigned_mode_a_code.code: uint32
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.previously_assigned_mode_a_code: message
# flight_record_report_stream.flight_record_update.flight_record.ssr_code_allocation_record.previously_assigned_mode_a_code.code: uint32
# flight_record_report_stream.flight_record_update.flight_record.special_status: message
# flight_record_report_stream.flight_record_update.flight_record.special_status.specialStatusCodes: repeated enum
# flight_record_report_stream.flight_record_update.flight_record.date_of_flight: message
# flight_record_report_stream.flight_record_update.flight_record.date_of_flight.seconds: int64
# flight_record_report_stream.flight_record_update.flight_record.date_of_flight.nanos: int32
# flight_record_report_stream.flight_record_update.flight_record.aircraft_registration: message
# flight_record_report_stream.flight_record_update.flight_record.aircraft_registration.aircraftregistration: string
# flight_record_report_stream.flight_record_update.flight_record.points_firs_and_accumulated_estimated_elapsed_times: repeated message
# flight_record_report_stream.flight_record_update.flight_record.points_firs_and_accumulated_estimated_elapsed_times.point_or_fir: string
# flight_record_report_stream.flight_record_update.flight_record.points_firs_and_accumulated_estimated_elapsed_times.time_over: message
# flight_record_report_stream.flight_record_update.flight_record.points_firs_and_accumulated_estimated_elapsed_times.time_over.milliseconds: sfixed64
# flight_record_report_stream.flight_record_update.flight_record.selcal_code: string
# flight_record_report_stream.flight_record_update.flight_record.additional_aircraft_types: string
# flight_record_report_stream.flight_record_update.flight_record.enroute_delay: repeated message
# flight_record_report_stream.flight_record_update.flight_record.enroute_delay.point_or_fir: string
# flight_record_report_stream.flight_record_update.flight_record.enroute_delay.time_over: message
# flight_record_report_stream.flight_record_update.flight_record.enroute_delay.time_over.milliseconds: sfixed64
# flight_record_report_stream.flight_record_update.flight_record.aircraft_operating_agency: string
# flight_record_report_stream.flight_record_update.flight_record.originators_address: string
# flight_record_report_stream.flight_record_update.flight_record.aircraft_performance_data: string
# flight_record_report_stream.flight_record_update.flight_record.enroute_alternate_aerodromes: string
# flight_record_report_stream.flight_record_update.flight_record.takeoff_alternate_aerodrome: string
# flight_record_report_stream.flight_record_update.flight_record.route_elements_to_revised_destination_aerodrome: string
# flight_record_report_stream.flight_record_update.flight_record.remarks: string
# flight_record_report_stream.flight_record_update.flight_record.correlation_record: message
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.track_number: message
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.track_number.value: uint32
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.state: enum
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.callsign_mismatch: bool
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.ssr_mismatch: bool
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.reported_mode_a_code: message
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.reported_mode_a_code.code: uint32
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.correlation_ambiguous: bool
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.callsign_mismatch_state: enum
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.ssr_mismatch_state: enum
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.correlation_ambiguous_state: enum
# flight_record_report_stream.flight_record_update.flight_record.correlation_record.correlation_target_lost: bool
# flight_record_report_stream.flight_record_update.flight_record.expanded_route: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements: repeated message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.designator: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_point_or_navaid.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_route: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designated_route.designator: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.designator: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_designator.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.designator: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.latlon: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.latlon.latitude: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.latlon.latitude.degrees: double
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.latlon.longitude: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.latlon.longitude.degrees: double
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_position_point.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.designator: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.designator: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_speed: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_speed.cruising_speed: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_level: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.planned_cruising_speed_and_level.cruising_level.cruising_level: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.planned_cruise_climb: message
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.planned_cruise_climb.cruise_climb: string
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.flight_rule_category: enum
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_designated_point_or_navaid.(oneof) planned_cruising_speed_and_level_or_cruise_climb: planned_cruising_speed_and_level, planned_cruise_climb
# flight_record_report_stream.flight_record_update.flight_record.expanded_route.expanded_route_elements.planned_route_element.planned_relative_point.planned_position_point: message
# ...
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.end_time.hours: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.end_time.minutes: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.end_time.seconds: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.scheduled_activation.preactive_time: message
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.scheduled_activation.preactive_time.milliseconds: sfixed64
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.scheduled_activation.(oneof) schedule: list_of_absolute_schedule, list_of_daily_or_monthly_schedule
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.override_vertical_limits: message
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.override_vertical_limits.lower_limit: message
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.override_vertical_limits.lower_limit.value: string
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.override_vertical_limits.lower_limit.unit_of_measurement: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.override_vertical_limits.lower_limit.reference: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.override_vertical_limits.upper_limit: message
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.override_vertical_limits.upper_limit.value: string
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.override_vertical_limits.upper_limit.unit_of_measurement: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.override_vertical_limits.upper_limit.reference: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_volume.free_text: string
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.unique_id: string
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.list_of_latlon: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.list_of_latlon.latitude: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.list_of_latlon.latitude.degrees: double
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.list_of_latlon.longitude: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.list_of_latlon.longitude.degrees: double
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.vertical_limits: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.vertical_limits.lower_limit: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.vertical_limits.lower_limit.value: string
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.vertical_limits.lower_limit.unit_of_measurement: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.vertical_limits.lower_limit.reference: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.vertical_limits.upper_limit: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.vertical_limits.upper_limit.value: string
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.vertical_limits.upper_limit.unit_of_measurement: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_list_of_latlon.vertical_limits.upper_limit.reference: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.volume_by_navdb_id: string
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.activation_status: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_absolute_schedule: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_absolute_schedule.absolute_schedules: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_absolute_schedule.absolute_schedules.start_time: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_absolute_schedule.absolute_schedules.start_time.seconds: int64
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_absolute_schedule.absolute_schedules.start_time.nanos: int32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_absolute_schedule.absolute_schedules.end_time: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_absolute_schedule.absolute_schedules.end_time.seconds: int64
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_absolute_schedule.absolute_schedules.end_time.nanos: int32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules.start_time: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules.start_time.hours: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules.start_time.minutes: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules.start_time.seconds: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules.end_time: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules.end_time.hours: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules.end_time.minutes: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules.end_time.seconds: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.daily_schedules.list_of_days: repeated enum
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.start_day: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.end_day: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.start_time: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.start_time.hours: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.start_time.minutes: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.start_time.seconds: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.end_time: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.end_time.hours: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.end_time.minutes: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.list_of_daily_or_monthly_schedule.monthly_schedules.end_time.seconds: sint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.preactive_time: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.preactive_time.milliseconds: sfixed64
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.scheduled_activation.(oneof) schedule: list_of_absolute_schedule, list_of_daily_or_monthly_schedule
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.warning_cycle: message
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.warning_cycle.conflict_threshold: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.warning_cycle.cycle_count: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.warning_cycle.maximum_age_sec: double
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.priority_rank: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.look_ahead_time_sec: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.imminent_time_sec: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.warning_time_sec: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.horizontal_buffer_nm: double
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.vertical_buffer_ft: double
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.apw_processing_parameter_group.active: bool
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.free_text: string
# safety_net_setting_stream.safety_net_state_update.safety_net_state_add_volume.(oneof) volume: volume_by_list_of_latlon, volume_by_navdb_id
# safety_net_setting_stream.safety_net_state_update.safety_net_activation_status: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_activation_status.type: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_activation_status.status: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibition_status: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibition_status.type: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibition_status.status: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.type: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes: message
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes.inhibited_ssr_codes: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes.inhibited_ssr_codes.single_ssr_code: message
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes.inhibited_ssr_codes.single_ssr_code.code: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes.inhibited_ssr_codes.range_ssr_codes: message
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes.inhibited_ssr_codes.range_ssr_codes.from_ssr_code: message
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes.inhibited_ssr_codes.range_ssr_codes.from_ssr_code.code: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes.inhibited_ssr_codes.range_ssr_codes.to_ssr_code: message
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes.inhibited_ssr_codes.range_ssr_codes.to_ssr_code.code: uint32
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_ssr_codes.inhibited_ssr_codes.inhibited_ssr_codes.(oneof) ssr_codes: single_ssr_code, range_ssr_codes
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_target_addresses: repeated message
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_target_addresses.type: enum
# safety_net_setting_stream.safety_net_state_update.safety_net_inhibited_target_addresses.inhibited_target_addresses: repeated string
# safety_net_setting_stream.safety_net_state_remove_volume: message
# safety_net_setting_stream.safety_net_state_remove_volume.unique_id: string
# safety_net_setting_stream.service_health_info: message
# safety_net_setting_stream.service_health_info.timestamp: message
# safety_net_setting_stream.service_health_info.timestamp.seconds: int64
# safety_net_setting_stream.service_health_info.timestamp.nanos: int32
# safety_net_setting_stream.service_health_info.data_model_info: message
# safety_net_setting_stream.service_health_info.data_model_info.data_model: enum
# safety_net_setting_stream.service_health_info.data_model_info.data_model_version: uint64
# safety_net_setting_stream.service_health_info.heartbeat_interval: message
# safety_net_setting_stream.service_health_info.heartbeat_interval.milliseconds: sfixed64
# safety_net_setting_stream.service_health_info.operational_status: enum
# safety_net_setting_stream.(oneof) safety_net_volumes_state: safety_net_state_update, safety_net_state_remove_volume
# (oneof) payload: track, flight_plan, trajectory, asd_event, alert, safetynet_volume, asterix, flight_record_report_stream, trajectory_response, safety_net_setting_stream
# ['timestamp', 'track', 'flight_plan', 'trajectory', 'asd_event', 'alert', 'safetynet_volume', 'asterix', 'flight_record_report_stream', 'trajectory_response', 'safety_net_setting_stream']

# %%
TZ = ZoneInfo("Europe/Zagreb")

def load_mouse_positions(db_path, start_epoch_ms, end_epoch_ms, limit=None, batch=20_000):
    """ Return a DataFrame with epoch_ms and:
      - 'asd_event.mouse_position.x' (Int32)
      - 'asd_event.mouse_position.y' (Int32)
    Only rows whose payload has the mouse_position message are populated"""

    # Read-only, immutable: faster & avoids locks
    con = sqlite3.connect(f"file:{db_path}?mode=ro&immutable=1", uri=True)
    con.text_factory = bytes
    # Read-only speed PRAGMAs (best-effort; safe if ignored)
    con.execute("PRAGMA query_only=ON")
    con.execute("PRAGMA mmap_size=268435456")        # 256 MiB
    con.execute("PRAGMA temp_store=MEMORY")

    sql = ('SELECT id, epoch_ms, payload FROM "events" '
           'WHERE epoch_ms BETWEEN ? AND ? '
           'ORDER BY epoch_ms')
    cur = con.execute(sql, (start_epoch_ms, end_epoch_ms))

    ids, epochs, xs, ys = [], [], [], []
    seen = 0
    while True:
        rows = cur.fetchmany(batch)
        if not rows:
            break
        for id_, ms, blob in rows:
            ev = messages_pb2.Event()
            ev.ParseFromString(blob)

            ae = getattr(ev, "asd_event", None)
            if ae is not None and ae.HasField("mouse_position"):
                # proto3 scalars default to 0; we only read them when the message exists
                x = int(ae.mouse_position.x)
                y = int(ae.mouse_position.y)
            else:
                x = y = None

            ids.append(int(id_))
            epochs.append(int(ms))
            xs.append(x)
            ys.append(y)

            seen += 1
            if limit is not None and seen >= int(limit):
                rows = []
                break
        if limit is not None and seen >= int(limit):
            break

    con.close()

    df = pd.DataFrame({
        "id": ids,
        "epoch_ms": epochs,
        "Mouse position X": pd.Series(xs, dtype="Int32"),
        "Mouse position Y": pd.Series(ys, dtype="Int32"),
    }).sort_values("epoch_ms").reset_index(drop=True)
    
    df = df.dropna()

    return df

# %%
DB = "/store/kruu/eye_tracking/training_data/010/Scenario 3/simulator/010_scenario_3/polaris-events-2025-09-04T15_04_14.db"
df_mouse = load_mouse_positions(DB, int(df_eye_tracking_sliced.epoch_ms.min()), int(df_eye_tracking_sliced.epoch_ms.max()))
# df_mouse = load_mouse_positions(DB, 1756995761392, 1756995771444) # for task '010_3_5_1'

# %%
df_mouse[["Mouse position X", "Mouse position Y"]].value_counts()
# Out:
# Mouse position X  Mouse position Y
# 1811              1012                5
# 1679              1196                5
# 1221              1815                4
# 1732              1433                4
# 1954              943                 4
#                                      ..
# 1778              1339                1
#                   1251                1
#                   1221                1
#                   1206                1
#                   1474                1
# Name: count, Length: 22297, dtype: int64

# %%
(~df_mouse[["Mouse position X", "Mouse position Y"]].isna()).sum()
# Out:
# Mouse position X    24535
# Mouse position Y    24535
# dtype: int64

# %%
df_mouse.dropna()
# Out:
#             id       epoch_ms  Mouse position X  Mouse position Y
# 13         500  1756994222789              2290              1069
# 16         503  1756994222989              2101              1085
# 18         505  1756994223090              1818              1100
# 20         507  1756994223190              1813              1100
# 25         512  1756994223497              1845              1089
# ...        ...            ...               ...               ...
# 126687  127174  1756997839919              3454               743
# 126688  127175  1756997840372              3257               566
# 126689  127176  1756997840522              3204               522
# 126690  127177  1756997840622              3203               521
# 126691  127178  1756997841228              3191               494
#
# [24535 rows x 4 columns]

# %% [markdown]
# # Merge ET + mouse: Full Union time

# %%
TZ = ZoneInfo("Europe/Zagreb")

dfe = df_eye_tracking_sliced.sort_values("epoch_ms").astype({"epoch_ms":"int64"})
dfm = df_mouse.sort_values("epoch_ms").astype({"epoch_ms":"int64"})

TOL = 8  # ms
timeline = pd.merge_asof(dfe, dfm, on="epoch_ms", direction="nearest", tolerance=8)

timeline["ts_utc"] = pd.to_datetime(timeline["epoch_ms"].astype("int64"), unit="ms", utc=True)
timeline["ts_cet"] = timeline["ts_utc"].dt.tz_convert(TZ)

# %%
timeline[["Mouse position X", "Mouse position Y"]].value_counts()
# Out:
# Mouse position X  Mouse position Y
# 1954              943                 9
# 1811              1012                8
# 1958              981                 6
# 2132              1502                6
# 1628              1320                6
#                                      ..
# 2575              1010                1
# 2571              79                  1
# 2572              546                 1
# 2568              469                 1
# 2569              594                 1
# Name: count, Length: 22148, dtype: int64
