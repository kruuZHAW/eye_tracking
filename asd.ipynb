# %%
import os
import sqlite3
import pandas as pd
import seaborn as sns
from pathlib import Path
from contextlib import closing
import matplotlib.pyplot as plt
from google.protobuf.json_format import MessageToDict

from events.gen import messages_pb2, asd_events_pb2
from utils.build_raw_inputs import find_sim_db, find_scenarios

ROOT = Path("/store/kruu/eye_tracking/training_data")
SAVE = Path("asd")

# %%
def build_df(pid: str, sid: str, db_dir: str, batch_size: int = 50_000):
    events = []
    event_obj = messages_pb2.Event()

    with closing(sqlite3.connect(f"{Path(db_dir).as_uri()}?immutable=1", uri=True)) as con:
        con.text_factory = bytes
        cur = con.cursor()
        cur.execute("SELECT epoch_ms, payload FROM events")
        
        while (rows := cur.fetchmany(batch_size)):
            for epoch_ms, payload in rows:
                event_obj.ParseFromString(payload)
                
                asd_event = event_obj.asd_event.WhichOneof("event")

                if asd_event is not None:
                    events.append((epoch_ms, asd_event, MessageToDict(getattr(event_obj.asd_event, asd_event)), pid, sid))

    return pd.DataFrame(events, columns=["epoch_ms", "event_name", "data", "participant", "scenario"])


for pid, sid, scen_dir in find_scenarios(ROOT):
    try:
        db_dir = find_sim_db(scen_dir)
        df = build_df(pid, sid, db_dir)
        print(f"[{pid} {sid}] Extracted {len(df):,} ASD events from {db_dir}")
        df.to_parquet(SAVE / f"p{pid}_s{sid}.parquet")
    
    except sqlite3.DatabaseError as e:
        print(f"[{pid} {sid}] DatabaseError: {e} {db_dir}")


pd.concat(pd.read_parquet(SAVE/f) for f in os.listdir(SAVE)).to_parquet(SAVE/"asd.parquet")
# Out:
# [001 1] Extracted 65,565 ASD events from /store/kruu/eye_tracking/training_data/001/Scenario 1/simulator/001_sept_scenario_1.db
# [001 2] Extracted 80,904 ASD events from /store/kruu/eye_tracking/training_data/001/Scenario 2/simulator/001_sept_scenario_2.db
# [001 3] Extracted 73,539 ASD events from /store/kruu/eye_tracking/training_data/001/Scenario 3/simulator/001_sept_scenario_3.db
# [002 1] Extracted 72,505 ASD events from /store/kruu/eye_tracking/training_data/002/Scenario 1/simulator/002_sept_scenario_1.db
# [002 2] Extracted 70,321 ASD events from /store/kruu/eye_tracking/training_data/002/Scenario 2/simulator/polaris-events-2025-09-10T07:59:22.db
# [002 3] Extracted 64,755 ASD events from /store/kruu/eye_tracking/training_data/002/Scenario 3/simulator/002_sept_scenario_3.db
# [003 1] Extracted 68,989 ASD events from /store/kruu/eye_tracking/training_data/003/Scenario 1/simulator/003_sept_scenario_1.db
# [003 2] Extracted 83,382 ASD events from /store/kruu/eye_tracking/training_data/003/Scenario 2/simulator/polaris-events-2025-09-26T14:43:32.db
# [003 3] Extracted 74,671 ASD events from /store/kruu/eye_tracking/training_data/003/Scenario 3/simulator/003_sept_scenario_3.db
# [004 1] Extracted 63,228 ASD events from /store/kruu/eye_tracking/training_data/004/Scenario 1/simulator/polaris-events-2025-09-10T09:23:09.db
# [004 2] Extracted 62,832 ASD events from /store/kruu/eye_tracking/training_data/004/Scenario 2/simulator/004_sept_scenario_1.db
# [004 3] Extracted 0 ASD events from /store/kruu/eye_tracking/training_data/004/Scenario 3/simulator/polaris-events-2025-09-11T08:13:02.db
# [005 1] Extracted 67,887 ASD events from /store/kruu/eye_tracking/training_data/005/Scenario 1/simulator/005_scenario_1.db
# [005 2] Extracted 77,041 ASD events from /store/kruu/eye_tracking/training_data/005/Scenario 2/simulator/polaris-events-2025-09-10T10:52:56.db
# [005 3] Extracted 68,402 ASD events from /store/kruu/eye_tracking/training_data/005/Scenario 3/simulator/005_sept_scenario_3.db
# [006 1] Extracted 83,933 ASD events from /store/kruu/eye_tracking/training_data/006/Scenario 1/simulator/polaris-events-2025-09-04T09:00:27.db
# [006 2] Extracted 86,600 ASD events from /store/kruu/eye_tracking/training_data/006/Scenario 2/simulator/006_sept_scenario_2.db
# [006 3] Extracted 89,044 ASD events from /store/kruu/eye_tracking/training_data/006/Scenario 3/simulator/006_sept_scenario_3.db
# [007 1] Extracted 64,453 ASD events from /store/kruu/eye_tracking/training_data/007/Scenario 1/simulator/007_sept_scenario_1.db
# [007 2] Extracted 54,381 ASD events from /store/kruu/eye_tracking/training_data/007/Scenario 2/simulator/007_sept_scenario_2.db
# [007 3] Extracted 87,344 ASD events from /store/kruu/eye_tracking/training_data/007/Scenario 3/simulator/007_sept_scenario_3.db
# [008 1] Extracted 80,329 ASD events from /store/kruu/eye_tracking/training_data/008/Scenario 1/simulator/008_sept_scenario_1.db
# [008 2] Extracted 89,170 ASD events from /store/kruu/eye_tracking/training_data/008/Scenario 2/simulator/008_sept_scenario_2.db
# [008 3] Extracted 75,917 ASD events from /store/kruu/eye_tracking/training_data/008/Scenario 3/simulator/008_sept_scenario_3.db
# [009 1] Extracted 67,010 ASD events from /store/kruu/eye_tracking/training_data/009/Scenario 1/simulator/009_scenario_1.db
# [009 2] DatabaseError: database disk image is malformed /store/kruu/eye_tracking/training_data/009/Scenario 2/simulator/009_sept_scenario_2.db
# [009 3] Extracted 80,278 ASD events from /store/kruu/eye_tracking/training_data/009/Scenario 3/simulator/polaris-events-2025-09-10T12:39:27.db
# [010 1] Extracted 77,942 ASD events from /store/kruu/eye_tracking/training_data/010/Scenario 1/simulator/polaris-events-2025-09-05T14:59:38.db
# [010 2] Extracted 92,447 ASD events from /store/kruu/eye_tracking/training_data/010/Scenario 2/simulator/polaris-events-2025-09-04T11:19:38.db
# [010 3] Extracted 80,642 ASD events from /store/kruu/eye_tracking/training_data/010/Scenario 3/simulator/010_scenario_3/polaris-events-2025-09-04T15_04_14.db
# [011 1] Extracted 84,757 ASD events from /store/kruu/eye_tracking/training_data/011/Scenario 1/simulator/011_sept_scenario_1.db
# [011 2] Extracted 112,515 ASD events from /store/kruu/eye_tracking/training_data/011/Scenario 2/simulator/011_sept_scenario_2.db
# [011 3] Extracted 97,065 ASD events from /store/kruu/eye_tracking/training_data/011/Scenario 3/simulator/011_sept_scenario_3.db
# [013 1] Extracted 23,489 ASD events from /store/kruu/eye_tracking/training_data/013/Scenario 1/simulator/polaris-events-2025-09-10T14:31:47.db
# [013 2] Extracted 82,637 ASD events from /store/kruu/eye_tracking/training_data/013/Scenario 2/simulator/013_sept_scenario_2.db
# [013 3] Extracted 75,836 ASD events from /store/kruu/eye_tracking/training_data/013/Scenario 3/simulator/013_sept_scenario_3.db
# [014 1] Extracted 77,323 ASD events from /store/kruu/eye_tracking/training_data/014/Scenario 1/simulator/014_sept_scenario_1.db
# [014 2] Extracted 79,497 ASD events from /store/kruu/eye_tracking/training_data/014/Scenario 2/simulator/014_sept_scenario_2.db
# [014 3] Extracted 72,321 ASD events from /store/kruu/eye_tracking/training_data/014/Scenario 3/simulator/014_sept_scenario_3_loss.db
# [015 1] Extracted 76,678 ASD events from /store/kruu/eye_tracking/training_data/015/Scenario 1/simulator/015_sept_scenario_1.db
# [015 2] Extracted 112,261 ASD events from /store/kruu/eye_tracking/training_data/015/Scenario 2/simulator/015_sept_scenario_2.db
# [015 3] Extracted 89,909 ASD events from /store/kruu/eye_tracking/training_data/015/Scenario 3/simulator/015_sept_scenario_3.db
# [016 1] Extracted 83,395 ASD events from /store/kruu/eye_tracking/training_data/016/Scenario 1/simulator/016_scenario_1.db
# [016 2] Extracted 107,596 ASD events from /store/kruu/eye_tracking/training_data/016/Scenario 2/simulator/016_sept_scenario_2.db
# [016 3] Extracted 101,609 ASD events from /store/kruu/eye_tracking/training_data/016/Scenario 3/simulator/016_scenario_2.db
# [017 1] Extracted 70,225 ASD events from /store/kruu/eye_tracking/training_data/017/Scenario 1/simulator/017_sept_scenario_1.db
# [017 2] Extracted 76,186 ASD events from /store/kruu/eye_tracking/training_data/017/Scenario 2/simulator/017_sept_scenario_2.db
# [017 3] Extracted 76,275 ASD events from /store/kruu/eye_tracking/training_data/017/Scenario 3/simulator/017_sept_scenario_3.db
# [018 1] Extracted 75,710 ASD events from /store/kruu/eye_tracking/training_data/018/Scenario 1/simulator/018_sept_scenario_1.db
# [018 2] Extracted 85,086 ASD events from /store/kruu/eye_tracking/training_data/018/Scenario 2/simulator/018_sept_scenario_2.db
# [018 3] Extracted 77,840 ASD events from /store/kruu/eye_tracking/training_data/018/Scenario 3/simulator/018_sept_scenario_3.db
# [019 1] Extracted 80,074 ASD events from /store/kruu/eye_tracking/training_data/019/Scenario 1/simulator/109_sept_scenario_1.db
# [019 2] Extracted 98,054 ASD events from /store/kruu/eye_tracking/training_data/019/Scenario 2/simulator/019_sept_scenario_2.db
# [019 3] Extracted 98,352 ASD events from /store/kruu/eye_tracking/training_data/019/Scenario 3/simulator/019_sept_scenario_3.db
# [020 1] Extracted 72,234 ASD events from /store/kruu/eye_tracking/training_data/020/Scenario 1/simulator/020_sept_scenario_1.db
# [020 2] Extracted 81,742 ASD events from /store/kruu/eye_tracking/training_data/020/Scenario 2/simulator/020_sept_scenario_2.db
# [020 3] Extracted 84,021 ASD events from /store/kruu/eye_tracking/training_data/020/Scenario 3/simulator/020_sept_scenario_3.db
# [023 1] Extracted 80,626 ASD events from /store/kruu/eye_tracking/training_data/023/Scenario 1/simulator/023_sept_scenario_1.db
# [023 2] Extracted 95,964 ASD events from /store/kruu/eye_tracking/training_data/023/Scenario 2/simulator/023_sept_scenario_2.db
# [023 3] Extracted 95,784 ASD events from /store/kruu/eye_tracking/training_data/023/Scenario 3/simulator/023_sept_scenario_3.db

# %%
df = pd.read_parquet(SAVE/"asd.parquet")
event_names = [field.name for field in asd_events_pb2.Event.DESCRIPTOR.oneofs_by_name["event"].fields]
df['event_name'] = pd.Categorical(df['event_name'], categories=event_names, ordered=True)
df
# Out:
#             epoch_ms             event_name  \
# index
# 0      1758697868960         mouse_position
# 1      1758697869010         mouse_position
# 2      1758697869110         mouse_position
# 3      1758697869110         mouse_position
# 4      1758697869160         mouse_position
# ...              ...                    ...
# 95779  1758285111511   track_label_position
# 95780  1758285114631  track_screen_position
# 95781  1758285114631   track_label_position
# 95782  1758285119138         mouse_position
# 95783  1758285119794         mouse_position
#
#                                                     data participant scenario
# index
# 0                                 {'x': 2539, 'y': 1788}         001        1
# 1                                 {'x': 2139, 'y': 1519}         001        1
# 2                                 {'x': 2045, 'y': 1320}         001        1
# 3                                 {'x': 2041, 'y': 1287}         001        1
# 4                                 {'x': 2041, 'y': 1100}         001        1
# ...                                                  ...         ...      ...
# 95779  {'x': 2741, 'y': 1014, 'width': 75, 'height': ...         023        3
# 95780  {'x': 2675, 'y': 1019, 'visible': True, 'fligh...         023        3
# 95781  {'x': 2742, 'y': 1014, 'width': 75, 'height': ...         023        3
# 95782                              {'x': 3557, 'y': 981}         023        3
# 95783                              {'x': 1739, 'y': 519}         023        3
#
# [4628572 rows x 5 columns]

# %%
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(12, 8))

sns.countplot(
    data=df,
    y="event_name",
    hue="scenario",
    ax=ax
)
ax.set_xscale('log')

ax.set_title("Distribution of Events by Scenario", fontsize=16, pad=20)
ax.set_xlabel("Count of Events", fontsize=12)
ax.set_ylabel("Event Name", fontsize=12)
ax.legend(title="Scenario", loc="lower right")

plt.tight_layout()
plt.show()

# %%
from matplotlib.ticker import FuncFormatter

# Create the base count matrix ---
count_matrix = pd.crosstab(df['event_name'], df['scenario'])


def number_formatter(x):
    if x >= 1_000_000:
        return f'{x*1e-6:.1f}M'
    if x >= 1_000:
        return f'{x*1e-3:.1f}k'
    return f'{int(x)}'


plt.style.use('default')
plt.figure(figsize=(8, 6), dpi=150)
heatmap = sns.heatmap(
    count_matrix,
    annot=True,
    fmt='d',
    linewidths=.5,
    cmap='viridis',
    cbar_kws={'format': FuncFormatter(number_formatter)}
)

# Apply custom number formatting function
for t in heatmap.texts:
    val = float(t.get_text())
    t.set_text(number_formatter(val))

plt.title('Event Count Heatmap', fontsize=16, pad=20)
plt.xlabel('Scenario', fontsize=12)
plt.ylabel('Event Name', fontsize=12)
plt.xticks(rotation=0) # Keep scenario labels horizontal
plt.yticks(rotation=0) # Keep event names horizontal

plt.tight_layout()
plt.show()
